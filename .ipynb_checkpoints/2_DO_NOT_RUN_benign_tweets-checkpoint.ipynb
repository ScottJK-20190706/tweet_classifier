# %% [markdown]
# ## Common imports

# %%
#Twitter code adapted from http://socialmedia-class.org/twittertutorial.html
#Twitter api docs at https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
import json
import tweepy
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ## Twitter api tokens and keys

# %%
api_key = 'almNhzSp4wcHZMcoHEQlAhbbF'
api_secret_key = 'SchcgoAOxYPQ0WEtZ5qJrO0A1Olw6JhAOofU3UP6my5toC17GY'
access_token = '253949942-XRrR5lcVXLBbfmaAHFBqfKOtL7RH6c22XQczFgXq'
access_token_secret = 'gkc8KI157akiLIeMJWd1SmZIt3GPU6EnQX3iZrXdtX7KQ'

# %% [markdown]
# ## Authenticate using tweepy

# %%
# Setup tweepy to authenticate with Twitter credentials:

#auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth = tweepy.AppAuthHandler(api_key, api_secret_key)
#auth.set_access_token(access_token, access_token_secret)

# Create the api to connect to twitter with your creadentials
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)
#---------------------------------------------------------------------------------------------------------------------
# wait_on_rate_limit= True;  will make the api to automatically wait for rate limits to replenish
# wait_on_rate_limit_notify= Ture;  will make the api  to print a notification when Tweepyis waiting for rate limits to replenish
#---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Function for getting tweets

# %%
def get_tweets(listOfTweets, keyword, numOfTweets,start_id,max_id,update):
    # Iterate through all tweets containing the given word, api search mode
    if update==1:
        tweets = tweepy.Cursor(api.search, q=keyword, tweet_mode='extended', since_id=str(start_id+1),max_id=str(max_id-1)).items(numOfTweets)
    if update==0:
        tweets = tweepy.Cursor(api.search, q=keyword, tweet_mode='extended', max_id=str(start_id-1)).items(numOfTweets)
        
    for tweet in tweets:
        try:
            #get results in json format
            status = tweet
            json_str = json.dumps(status._json)
            json_str = json.loads(json_str)
            
            #get the necessary values from each tweet
            id = json_str['id']
            screen_name = json_str['user']['screen_name']
            user_name = json_str['user']['name']
            followers = json_str['user']['followers_count']
            following = json_str['user']['friends_count']
            tweet_created_at = json_str['created_at']
            tweet_text = json_str['full_text']
            bio = json_str['user']['description']
            location = json_str['user']['location']
            #coord = json_str['coordinates']['coordinates']
            coord = ''
            no_tweets = json_str['user']['statuses_count']

            if len(json_str['entities']['hashtags'])==0:
                hashtags = ''
            else:
                hashtags = []
                for i in range(0,len(json_str['entities']['hashtags'])):
                    hashtags = pd.Series(np.append(hashtags,json_str['entities']['hashtags'][i]['text']))
                    hashtags = hashtags.str.cat(sep=' ')

            if len(json_str['entities']['urls'])==0:
                urls=''
            else:
                urls = []
                for i in range(0,len(json_str['entities']['urls'])):
                    urls = pd.Series(np.append(urls,json_str['entities']['urls'][i]['url']))
                    urls = urls.str.cat(sep=' ')

            if len(json_str['entities']['user_mentions'])==0:
                mentions = ''
            else:
                mentions = []
                for i in range(0,len(json_str['entities']['user_mentions'])):
                    mentions = pd.Series(np.append(mentions,json_str['entities']['user_mentions'][i]['screen_name']))
                    mentions = mentions.str.cat(sep=' ')

            # Add tweets in this format
            dict_ = {'Tweet ID': id,
                    'Name': screen_name,
                    'Username': user_name,
                    'Number of Followers': followers,
                    'Number Following': following,
                    'Time': tweet_created_at,
                    'Tweet': tweet_text,
                     'Hashtags': hashtags,
                     'Web': urls,
                     'Bio': bio,
                     'Location': location,
                     'Location Coordinates': coord,
                     'Number of Tweets': no_tweets,
                     'Mentions': mentions
                    }
            listOfTweets.append(dict_)
        except:
            pass 
    return listOfTweets

# %% [markdown]
# ## Get tweets

# %%
listOfTweets=[] #empty array for holding tweets
#search terms
keyword = '(nicola sturgeon) OR (snp sturgeon)  OR (scotland sturgeon) OR (scottish sturgeon) OR (holyrood sturgeon)  OR (westminster sturgeon) -filter:retweets'
#no of tweets per page
numOfTweets = 100

try:
    existing_data = pd.read_pickle('pickle_files/existing_data.pickle') #if database of tweets already exists
    existing_data.to_pickle('pickle_files/existing_data_backup.pickle')
    print("success")
    since_id = max(existing_data['Tweet ID']) #find the max tweetd id from existing database
    max_id = 9999999999999999999
    for i in range(0,30):
        x = get_tweets(listOfTweets, keyword, numOfTweets, since_id,max_id,1) #get tweets with tweetd id > since_id
        df = pd.DataFrame(x) #convert to dataframe
        max_id = min(df['Tweet ID']) #reset since_id
    existing_data = existing_data.append(df) #append new results to exisiting results
    existing_data = existing_data.reset_index(drop=True) #reset the index
    existing_data = existing_data.drop_duplicates() #just in case!
    existing_data.to_pickle('pickle_files/existing_data.pickle') #save the dataframe
except: #database of tweets does not yet exist
    pass
    #print("failure")
    #max_id=1150486892451946496 #this is the start point for this exercise
    #for i in range(0,30):
    #    x = get_tweets(listOfTweets, keyword, numOfTweets, max_id,0) #get tweets with tweet id < max_id
    #    df = pd.DataFrame(x) #convert to dataframe
    #    max_id = min(df['Tweet ID']) #reset max_id
    #df.to_pickle('pickle_files/existing_data.pickle') #save the dataframe
# Out:
# success

# %%
existing_data = pd.read_pickle('pickle_files/existing_data.pickle')
print(existing_data.shape)
# Out:
# (14804, 14)

# %% [markdown]
# ## Save csv file of all Nicola Sturgeon tweets

# %%
existing_data = pd.read_pickle('pickle_files/existing_data.pickle')
existing_data.to_csv('csv_excel/ns_tweets.csv')

# %% [markdown]
# ## Remove all tweets that contain a term from hatebase

# %%
hate_tweets = [] #to hold list of ids containing 'hatebase' terms
counter = 1
hate_terms = pd.read_pickle('pickle_files/hate_terms.pickle') #read in the terms from hatebase
hate_lower = hate_terms.hate_terms.str.lower() #lowercase all hate terms
existing_data_lower = pd.read_pickle('pickle_files/existing_data.pickle') #read in all the Nicola Sturgeon tweets
existing_data_lower.Tweet = existing_data_lower.Tweet.str.lower() #lowercase the Nicola Sturgeon tweets
chars = [' ','!','.'] #additional leading and trailing characters for the hatebase terms
for t in hate_lower: #loop through each hatebase term
    for lead in chars:
        for trail in chars:
            try:
                term = lead + t + trail #add the lead and trail characters
                hate_twitter = existing_data_lower[existing_data_lower.Tweet.str.contains(term)]
                hate_tweets = np.append(hate_tweets,hate_twitter.index) #add the index if the tweet contains a hatebase term
            except:
                pass
hate_tweets = np.unique(hate_tweets) #remove the duplicates
existing_clean = pd.read_pickle('pickle_files/existing_data.pickle')
existing_clean = existing_clean[~existing_clean.index.isin(hate_tweets)] #drop all the Nicola Sturgeon tweets that include a hatebase term

existing_clean.to_pickle('pickle_files/existing_clean.pickle') #save the dataframe of "clean" tweets
existing_clean.to_csv('csv_excel/ns_tweets_clean.csv') #save the dataframe of "clean" tweets

# %%
existing_clean.shape
# Out:
# (5706, 14)

# %% [markdown]
# ## Train test split

# %%
existing_hate_formatted['class'] = 1
existing_clean_formatted['class'] = 0
df = existing_hate_formatted.append(existing_clean_formatted)

from sklearn.utils import shuffle
df = shuffle(df, random_state=42)

from sklearn.model_selection import train_test_split
train_data_formatted,eval_data_formatted = train_test_split(df, test_size=0.2, random_state=42)

train_data_formatted.to_pickle('pickle_files/train_data_formatted.pickle')
eval_data_formatted.to_pickle('pickle_files/eval_data_formatted.pickle')

# %% [markdown]
# ## Dataset sizes

# %%
api = pd.read_pickle('pickle_files/api_formatted.pickle')
benign = pd.read_pickle('pickle_files/benign_formatted.pickle')
offensive = pd.read_pickle('pickle_files/offensive_formatted.pickle')
eval_data = pd.read_pickle('pickle_files/eval_data_formatted.pickle')
train_data = pd.read_pickle('pickle_files/train_data_formatted.pickle')
print("api shape "+ str(api.shape))
print("benign shape "+ str(benign.shape))
print("offensive shape "+ str(offensive.shape))
print("eval_data "+ str(eval_data.shape))
print("eval_data class 1 "+str(eval_data[eval_data['class']==1].shape))
print("eval_data class 0 "+str(eval_data[eval_data['class']==0].shape))
print("train_data "+ str(train_data.shape))
print("train_data class 1 "+str(train_data[train_data['class']==1].shape))
print("train_data class 0 "+str(train_data[train_data['class']==0].shape))
# Out:
# api shape (14538, 14)
# benign shape (5477, 14)
# offensive shape (839, 15)
# eval_data (1264, 16)
# eval_data class 1 (168, 16)
# eval_data class 0 (1096, 16)
# train_data (5052, 16)
# train_data class 1 (671, 16)
# train_data class 0 (4381, 16)

# %%
print(api.columns)
print(offensive.columns)
print(eval_data.columns)
# Out:
# Index(['Bio', 'Hashtags', 'Location', 'Location Coordinates', 'Mentions',
#        'Name', 'Number Following', 'Number of Followers', 'Number of Tweets',
#        'Time', 'Tweet', 'Tweet ID', 'Username', 'Web'],
#       dtype='object')
# Index(['Bio', 'Hashtags', 'Location', 'Location Coordinates', 'Mentions',
#        'Name', 'Number Following', 'Number of Followers', 'Number of Tweets',
#        'Retweeted ID', 'Time', 'Tweet', 'Tweet ID', 'Username', 'Web'],
#       dtype='object')
# Index(['Bio', 'Hashtags', 'Location', 'Location Coordinates', 'Mentions',
#        'Name', 'Number Following', 'Number of Followers', 'Number of Tweets',
#        'Retweeted ID', 'Time', 'Tweet', 'Tweet ID', 'Username', 'Web',
#        'class'],
#       dtype='object')

# %%
ex_hate = pd.read_pickle('pickle_files/existing_hate.pickle').reset_index()
ex_hate_formatted = pd.read_pickle('pickle_files/offensive_formatted.pickle').reset_index()
for i in range(100,200):
    print(ex_hate.loc[i,'Tweet'])
    print(ex_hate_formatted.loc[i,'Tweet'])
    print("")
# Out:
# Nicola Sturgeon is a cunt. She's always been a cunt and she'll always be a cunt.
# Nicola Sturgeon is a cunt. She's always been a cunt and she'll always be a cunt.
#
# @24HOURBANKING I'd like her to execute Nicola Sturgeon first.
# I'd like her to execute Nicola Sturgeon first.
#
# Can #scots not hang #Sturgeon for treachery to democracy? Majority vote count for nought https://t.co/lHCztGN0ga via https://t.co/zQbRDTH8su
# Can  not hang  for treachery to democracy? Majority vote count for nought  via
#
# Nicole Sturgeon Does my nut in bring us some haggis u ugly slag
# Nicole Sturgeon Does my nut in bring us some haggis u ugly slag
#
# Someone needs to shoot Nicola sturgeons head off
# Someone needs to shoot Nicola sturgeons head off
#
# Can someone shoot Sturgeon please??? Any takers?? Talks out of her arse!!!
# Can someone shoot Sturgeon please??? Any takers?? Talks out of her arse!!!
#
# Nicola Sturgeon in the remain campaign is enough to make you vote leave, one of those faces you really want to smash with a baseball bat
# Nicola Sturgeon in the remain campaign is enough to make you vote leave, one of those faces you really want to smash with a baseball bat
#
# Feel sorry for the poor husband of Nicola Sturgeon. She don't shut up and fuck me she's proper pig ugly. Anoying fucking troll.
# Feel sorry for the poor husband of Nicola Sturgeon. She don't shut up and fuck me she's proper pig ugly. Anoying fucking troll.
#
# @Fubar1872 correct and that Sturgeon wants her ginger Jimmy Krankie cunt kicking in. Her and Salmond are a disgrace😳
# correct and that Sturgeon wants her ginger Jimmy Krankie cunt kicking in. Her and Salmond are a disgrace😳
#
# right on.. pull may into line first... and assassinate that half wit sturgeon https://t.co/b4wBng6AaB
# right on.. pull may into line first... and assassinate that half wit sturgeon
#
# &lt;&lt;&lt;Sturgeon would be strung up from a lamppost within a couple of years of independence as the population starves https://t.co/nk5duPOKvs
# &lt;&lt;&lt;Sturgeon would be strung up from a lamppost within a couple of years of independence as the population starves
#
# If l did want scottish independance l would call for Sturgeon to be strung up for treason but all be said give the it and watch them starve
# If l did want scottish independance l would call for Sturgeon to be strung up for treason but all be said give the it and watch them starve
#
# @Danceive I hope Nicola Sturgeon dies horrific lee she look lika trout
# I hope Nicola Sturgeon dies horrific lee she look lika trout
#
# Nicola Sturgeon is the biggest cunt ever. I actually hate her with every bone in my body
# Nicola Sturgeon is the biggest cunt ever. I actually hate her with every bone in my body
#
# Another reason the bitch needs a kicking for. I've never been shy of saying it but fuck Sturgeon and fuck her SNP. https://t.co/DM6HrQ4M0G
# Another reason the bitch needs a kicking for. I've never been shy of saying it but fuck Sturgeon and fuck her SNP.
#
# Could easily uppercut Nicola Sturgeon in the jaw #JustSaying
# Could easily uppercut Nicola Sturgeon in the jaw
#
# I'm definitely NOT a violent person, but someone needs to get hold of Nicola sturgeon and give her a damn good slapping
# I'm definitely NOT a violent person, but someone needs to get hold of Nicola sturgeon and give her a damn good slapping
#
# Nicola Sturgeon is one woman I'd love to slap the fuck out of 🖐
# Nicola Sturgeon is one woman I'd love to slap the fuck out of 🖐
#
# I hate Nicola jimmy cranky sturgeon
# I hate Nicola jimmy cranky sturgeon
#
# Nicola Sturgeon.The Queen has had your bed made up in the tower.
# Nicola Sturgeon.The Queen has had your bed made up in the tower.
#
# Wish that stupid bint Nicola sturgeon would fuck off
# Wish that stupid bint Nicola sturgeon would fuck off
#
# @6ame fuck indyref2.   torn faced boot is going to ruin this bloody country.  Fuck off sturgeon ya tramp.
# fuck indyref2.   torn faced boot is going to ruin this bloody country.  Fuck off sturgeon ya tramp.
#
# Nobody I hate more than Nicola sturgeon
# Nobody I hate more than Nicola sturgeon
#
# Fuck off Sturgeon https://t.co/Vzofyl5enj
# Fuck off Sturgeon
#
# Fuck off Scotland!.... and take that sour face cunt Sturgeon with you!!
# Fuck off Scotland!.... and take that sour face cunt Sturgeon with you!!
#
# Nicola Sturgeon is on the same level as Hitler in my opinion
# Nicola Sturgeon is on the same level as Hitler in my opinion
#
# Fuck off Sturgeon, twat.
# Fuck off Sturgeon, twat.
#
# Nicola sturgeon is a lesbian nazi
# Nicola sturgeon is a lesbian nazi
#
# Nicola Sturgeon wants to descend Scotland into another civil war .. How did that turn out for ya ? Hung Drawn and Quartered #williamwallace
# Nicola Sturgeon wants to descend Scotland into another civil war .. How did that turn out for ya ? Hung Drawn and Quartered
#
# In all honesty, if I could get away with punching just one person in the face it would definitely be Nicola Sturgeon.
# In all honesty, if I could get away with punching just one person in the face it would definitely be Nicola Sturgeon.
#
# @NicolaSturgeon proper cunt you arent you sturgeon.
# Nobody ever asks the english if we want you scots as neighbours
# We dont
# Fuck off Irn Bru
# proper cunt you arent you sturgeon.
# Nobody ever asks the english if we want you scots as neighbours
# We dont
# Fuck off Irn Bru
#
# Nicola Sturgeon is a stupid fat bint we said NO once and we'll do it again🇬🇧🇬🇧🇬🇧 God save our queen
# Nicola Sturgeon is a stupid fat bint we said NO once and we'll do it again🇬🇧🇬🇧🇬🇧 God save our queen
#
# @DavidJo52951945 Nicola Sturgeon should be charged, tried, convicted, and hanged for treason! #indyref2 #uk #ukpoli #ScotRef
# Nicola Sturgeon should be charged, tried, convicted, and hanged for treason!
#
# I despise Nicola sturgeon wow
# I despise Nicola sturgeon wow
#
# I fucking hate Nicola Sturgeon, silly cow that she is
# I fucking hate Nicola Sturgeon, silly cow that she is
#
# Every time I see Nicole sturgeon I just think she is even more a bigger cunt then I thought before. Stick her trump corbyn on a raft at sea
# Every time I see Nicole sturgeon I just think she is even more a bigger cunt then I thought before. Stick her trump corbyn on a raft at sea
#
# Sturgeon on about another vote for Sweaty Sock independence AGAIN. Fucksake, can we just vote for her to Fuck off.
# #jockreferendum
# Sturgeon on about another vote for Sweaty Sock independence AGAIN. Fucksake, can we just vote for her to Fuck off.
#
# Fuck off sturgeon you witch
# Fuck off sturgeon you witch
#
# @tory_talk Arrest Nicola Sturgeon for treason and throw her in the tower! Just a thought...
# Arrest Nicola Sturgeon for treason and throw her in the tower! Just a thought...
#
# Nicola Sturgeon talks constant shite, a face I would never get sick of slapping👋✋
# Nicola Sturgeon talks constant shite, a face I would never get sick of slapping👋✋
#
# @chocolaticlair @scotlandinunion @SirBasilBrush I'm not signing this but if someone starts a petition to put Sturgeon in the tower I'm there
# I'm not signing this but if someone starts a petition to put Sturgeon in the tower I'm there
#
# Can't we just eject Scotland from the UK?  They're becoming a real pain in the arse
# Or do Sturgeon for treason and lock her in the tower?
# Can't we just eject Scotland from the UK?  They're becoming a real pain in the arse
# Or do Sturgeon for treason and lock her in the tower?
#
# Nicola Sturgeon needs shooting in the throat repeatedly with an elastic band gun #nutjob
# Nicola Sturgeon needs shooting in the throat repeatedly with an elastic band gun
#
# It's still in law that you may shoot a Scotsman with a bow and arrow on a Sunday. Roll on the 19th Sturgeon. #oldschoolsniper
# It's still in law that you may shoot a Scotsman with a bow and arrow on a Sunday. Roll on the 19th Sturgeon.
#
# Fuck off Nicola Sturgeon
# Fuck off Nicola Sturgeon
#
# Nicola sturgeon is a fucking fenian carpet muncher
# Nicola sturgeon is a fucking fenian carpet muncher
#
# I really do despise Sturgeon
# I really do despise Sturgeon
#
# I put the news on and it's fuckin Sturgeon again,someone please just shoot her#yawnyawn#f**koff
# I put the news on and it's fuckin Sturgeon again,someone please just shoot her**koff
#
# Fuck off sturgeon! Build a wall ffs https://t.co/Z0ZHsfeTiL
# Fuck off sturgeon! Build a wall ffs
#
# Why doesn't the queen just throw Sturgeon in the Tower of London for Treason. How they would have done it in the past
# Why doesn't the queen just throw Sturgeon in the Tower of London for Treason. How they would have done it in the past
#
# GINA MILLER - thanks
#
# NICHOLA STURGEON - fuck off
#
# 🇬🇧🇬🇧🇬🇧🇬🇧🎈🎉🎊🎉🎈
# GINA MILLER - thanks
#
# NICHOLA STURGEON - fuck off
#
# 🇬🇧🇬🇧🇬🇧🇬🇧🎈🎉🎊🎉🎈
#
# I want to punch nicola sturgeon in the face
# I want to punch nicola sturgeon in the face
#
# Just wish sturgeon would fuck off and die!!!!!
# Just wish sturgeon would fuck off and die!!!!!
#
# Sturgeon fuck off vote u out off Britain and Scotland Ffs da wan
# Sturgeon fuck off vote u out off Britain and Scotland Ffs da wan
#
# Guarantee nicola sturgeon still tries to hold a referendum anyway,
#
# Hope she does and gets done for treason....
# Guarantee nicola sturgeon still tries to hold a referendum anyway,
#
# Hope she does and gets done for treason....
#
# @JuliaHB1 why hasn't Sturgeon been thrown into the tower. ??
# why hasn't Sturgeon been thrown into the tower. ??
#
# Where does this fuckin cow sturgeon get off     we already voted no !!    Little fuckin bastard Hitler cow
# Where does this fuckin cow sturgeon get off     we already voted no !!    Little fuckin bastard Hitler cow
#
# Nicola Sturgeon needs ta fuck off
# Nicola Sturgeon needs ta fuck off
#
# @Maxie_UK @NicolaSturgeon So, if Sturgeon is worse than Thatcher,and Thatcher is worse than Hitler,that means Sturgeon is worse than Hitler.
# So, if Sturgeon is worse than Thatcher,and Thatcher is worse than Hitler,that means Sturgeon is worse than Hitler.
#
# @LBC Scotland and that silly midget sturgeon can fuck off. They're both totally useless
# Scotland and that silly midget sturgeon can fuck off. They're both totally useless
#
# we should have a referendum on deporting Nicola Sturgeon #sweaty #fuckoff
# we should have a referendum on deporting Nicola Sturgeon
#
# Nicola Sturgeon needs to fuck off I am Scottish living in England and want to vote Scotland out piss off giving them a vote let England vote
# Nicola Sturgeon needs to fuck off I am Scottish living in England and want to vote Scotland out piss off giving them a vote let England vote
#
# There is nobody I despise more than Nicola Sturgeon. What a horrid, horrid woman.
# There is nobody I despise more than Nicola Sturgeon. What a horrid, horrid woman.
#
# I really loathe Nicola sturgeon!!
# I really loathe Nicola sturgeon!!
#
# @Dorothy_Aidulis @CllrLMcDonald Of course I am. I loathe Sturgeon and her hate filled incompetent nationalists.
# Of course I am. I loathe Sturgeon and her hate filled incompetent nationalists.
#
# God I HATE Nicola Sturgeon!
# God I HATE Nicola Sturgeon!
#
# I despise Nicola Sturgeon and everything she stands for
# I despise Nicola Sturgeon and everything she stands for
#
# Good wee woman may shut that crazy bitch up cya sturgeon 🥔🔫 https://t.co/Fik58EFXMl
# Good wee woman may shut that crazy bitch up cya sturgeon 🥔🔫
#
# Send Sturgeon to the Tower &amp; chop off her head for sedition
# Scotland's future: What are Theresa May's options? - https://t.co/fRn3P03Wbr
# Send Sturgeon to the Tower &amp; chop off her head for sedition
# Scotland's future: What are Theresa May's options? -
#
# Despise Nicola sturgeon
# Despise Nicola sturgeon
#
# Nicola Sturgeon needs to seriously fuck off!
# Nicola Sturgeon needs to seriously fuck off!
#
# I actually despise Nicola sturgeon
# I actually despise Nicola sturgeon
#
# Nicola sturgeon is a nazi cow
# Nicola sturgeon is a nazi cow
#
# Fucking despise Nicola Sturgeon. Horrible women driven by hate.
# Fucking despise Nicola Sturgeon. Horrible women driven by hate.
#
# Is Nicola Sturgeon a lesbian or is that just what scottish women look like?
# Is Nicola Sturgeon a lesbian or is that just what scottish women look like?
#
# The only politician I truly despise, old "Vinegar Tits" Sturgeon.
#
# #nicolasturgeon
# The only politician I truly despise, old "Vinegar Tits" Sturgeon.
#
# Nicola Sturgeon please fuck off
# Nicola Sturgeon please fuck off
#
# Fuck off nicola sturgeon #bootface
# Fuck off nicola sturgeon
#
# if i see one more thing about nicola sturgeon trying to get independence, i'm going to find her and punch her in the fucking face.
# if i see one more thing about nicola sturgeon trying to get independence, i'm going to find her and punch her in the fucking face.
#
# I loathe the SNP. Sturgeon has one of those faces that you want to punch! Thank God, for the TV remote :) https://t.co/CvZfyxt6pb
# I loathe the SNP. Sturgeon has one of those faces that you want to punch! Thank God, for the TV remote :)
#
# BREAKING FAKE NEWS: #Sturgeon and @AlexSalmond to be exiled on #Ailsa Craig with the rest of their treasonous Fenian gang.
# BREAKING FAKE NEWS:  and  to be exiled on  Craig with the rest of their treasonous Fenian gang.
#
# Sturgeon for the Tower! #sturgeon
# Sturgeon for the Tower!
#
# Please can Nicola sturgeon just fuck off back to wherever she left her lips. Ugly irritating fucking cunt
# Please can Nicola sturgeon just fuck off back to wherever she left her lips. Ugly irritating fucking cunt
#
# Nicola Sturgeon is a fat lesbian bitch
# Nicola Sturgeon is a fat lesbian bitch
#
# Nicola Sturgeon will bite the bullet! Majority Scotts will kick her in her goofy teeth for trying to drag Scotland down against its will!🇬🇧
# Nicola Sturgeon will bite the bullet! Majority Scotts will kick her in her goofy teeth for trying to drag Scotland down against its will!🇬🇧
#
# Let's be fair Nicola Sturgeon is a cunt.
# Let's be fair Nicola Sturgeon is a cunt.
#
# Don't ya just wanna punch Nicola Sturgeon in the teeth
# Don't ya just wanna punch Nicola Sturgeon in the teeth
#
# Dont think I would ever get tired of kicking Nicola Sturgeon in the face..
# Dont think I would ever get tired of kicking Nicola Sturgeon in the face..
#
# Nicola Sturgeon is a fucking dyke
# Nicola Sturgeon is a fucking dyke
#
# @theresa_may Do us all a favour up here​ in Scotland, and lock Sturgeon in London tower please.
# Do us all a favour up here​ in Scotland, and lock Sturgeon in London tower please.
#
# How on earth has Nicola sturgeon not been shot in the head yet
# How on earth has Nicola sturgeon not been shot in the head yet
#
# Nicola Sturgeon is a fucking old boooot
# Nicola Sturgeon is a fucking old boooot
#
# I'm 100% Scottish and would send Nicola " Wee Jimmy Krankie" Sturgeon to the Tower of London for her treachery. https://t.co/cSydRWV7MB
# I'm 100% Scottish and would send Nicola " Wee Jimmy Krankie" Sturgeon to the Tower of London for her treachery.
#
# Nicola sturgeon talking daft again, this woman should be charged with treason. The worst this we did was give Scotland a parliament.
# Nicola sturgeon talking daft again, this woman should be charged with treason. The worst this we did was give Scotland a parliament.
#
# Sturgeon The duplicitous traitor. Honestly wish this was still medieval times so we could hoist her head onto a spike on London bridge.
# Sturgeon The duplicitous traitor. Honestly wish this was still medieval times so we could hoist her head onto a spike on London bridge.
#
# Nicola sturgeon should have her head on a spike for crimes against the empire. She got BTFO once and it'll happen again.
# Nicola sturgeon should have her head on a spike for crimes against the empire. She got BTFO once and it'll happen again.
#
# Nicola Sturgeon is a fucking cunt!!
# Nicola Sturgeon is a fucking cunt!!
#
# I wish someone would through Sturgeon in the Clyde the fuckin mess, she loves the sound of her own voice that wee prick
# I wish someone would through Sturgeon in the Clyde the fuckin mess, she loves the sound of her own voice that wee prick
#
# @MailOnline How about a practice shot, aimed at Nicola Sturgeon?
# How about a practice shot, aimed at Nicola Sturgeon?
#
# My hatred for Nicola Sturgeon grows daily the ugly we lesbian rug munching cunt
# My hatred for Nicola Sturgeon grows daily the ugly we lesbian rug munching cunt
