# %% [markdown]
# ## Common Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load data

# %%
eval_data_formatted = pd.read_pickle('pickle_files/eval_data_formatted.pickle') #raw evaluation data for referencing
eval_data_formatted['Tweet ID'] = eval_data_formatted['Tweet ID'].astype(str) #set tweet id type as string
class_results_local = pd.read_pickle('results/preds_per_tweet_local.pickle') #tweet by tweet classifications per model local
class_results_colab = pd.read_pickle('results/preds_per_tweet_colab.pickle') #tweet by tweet classifications per model colab
class_results = class_results_local.append(class_results_colab)
metrics_local = pd.read_pickle('results/metrics_local.pickle') #overall metrics per model local
metrics_colab = pd.read_pickle('results/metrics_colab.pickle') #overall metrics per model colab
metrics = metrics_local.append(metrics_colab)
actual = pd.read_pickle('features/df_tweet_eval.pickle') #get the actual classifications per tweet
actual_class = actual.loc[:,['tweet_id','class_column']] #get the actual classifications per tweet
# Out:
# C:\Users\scott\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
add_info = pd.read_csv('add_info.csv', encoding='latin')
metrics = pd.merge(metrics, add_info, on='tf')

# %%
metrics.to_csv('metrics.csv')
class_results.to_csv('class_results.csv')

# %%
class_results['desc'] = class_results['model']+ ' model using '+class_results['file']
class_results_pivot = class_results.pivot(index='tweet_id',columns='desc',values='pred').reset_index()
class_results.to_csv('class_results.csv')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plot_data = metrics.copy()

# Generate Data
p = plot_data.p
r = plot_data.r
groups = metrics.groupby('name')

# Plot
fig, ax = plt.subplots(figsize=(10,10))
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.p, group.r, marker='o', linestyle='', ms=10, label=name)
ax.legend(loc='upper right', bbox_to_anchor=(0.5, 0.95),
          ncol=2, fancybox=True, shadow=True)
ax.set_xticks(np.arange(0, 1, 0.1))
ax.set_yticks(np.arange(0, 1., 0.1))
plt.grid()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plot_data = metrics.copy()

#plot_data = plot_data[plot_data.calc!='n/a']

# Generate Data
p = plot_data.p
r = plot_data.r
groups = metrics.groupby('group')

# Plot
fig, ax = plt.subplots(figsize=(10,10))
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.p, group.r, marker='o', linestyle='', ms=10, label=name)
ax.legend(loc='upper right', bbox_to_anchor=(0.5, 0.95),
          ncol=2, fancybox=True, shadow=True)
ax.set_xticks(np.arange(0, 1, 0.1))
ax.set_yticks(np.arange(0, 1., 0.1))
plt.grid()
plt.show()

# %%
metrics.columns
# Out:
# Index(['Unnamed: 0', 'acc', 'auc_sc', 'bp', 'f_1', 'fn', 'fp', 'name', 'p',
#        'r', 'tf', 'tn', 'tp', 'group', 'features', 'calc', 'Unnamed: 4'],
#       dtype='object')

# %%
import seaborn as sns
sns.set(style="whitegrid")
plt.figure(figsize=(16, 6))

group_field = 'group'
metric_field = 'f_1'
plot_data = metrics.copy()

x = plot_data.groupby([group_field], sort=True)[metric_field].max().reset_index()
x = x.sort_values(by=metric_field, ascending=False)


sort = x[group_field]
ax = sns.boxplot(x=group_field, y=metric_field, data=plot_data, order=sort)
ax = sns.swarmplot(x=group_field, y=metric_field, data=plot_data, color=".25", order=sort, size=10)

# %%
import seaborn as sns
sns.set(style="whitegrid")
plt.figure(figsize=(16, 6))

group_field = 'name'
metric_field = 'f_1'
plot_data = metrics[metrics['group'].isin(['classic vector space','classic word embeddings'])]
update = {'ensemble (lr,svc,dt,rf)':'ensemble','ensemble (lr,svc)':'ensemble'}
plot_data = plot_data.replace({"name": update})

x = plot_data.groupby([group_field], sort=True)[metric_field].max().reset_index()
x = x.sort_values(by=metric_field, ascending=False)


sort = x[group_field]
ax = sns.boxplot(x=group_field, y=metric_field, data=plot_data, order=sort)
ax = sns.swarmplot(x=group_field, y=metric_field, data=plot_data, color=".25", order=sort, size=10)

# %%
import seaborn as sns
sns.set(style="whitegrid")
plt.figure(figsize=(16, 6))

group_field = 'features'
metric_field = 'f_1'
plot_data = metrics[metrics['group'].isin(['classic vector space','classic word embeddings'])]
plot_data = plot_data[~plot_data['name'].isin(['rf','dt'])]
update = {'ensemble (lr,svc,dt,rf)':'ensemble','ensemble (lr,svc)':'ensemble'}
plot_data = plot_data.replace({"name": update})

x = plot_data.groupby([group_field], sort=True)[metric_field].max().reset_index()
x = x.sort_values(by=metric_field, ascending=False)


sort = x[group_field]
ax = sns.boxplot(x=group_field, y=metric_field, data=plot_data, order=sort)
ax = sns.swarmplot(x=group_field, y=metric_field, data=plot_data, color=".25", order=sort, size=10)

# %%
plot_data = metrics[metrics['group'].isin(['classic vector space','classic word embeddings'])]
plot_data = plot_data[~plot_data['name'].isin(['lr','dt'])]
plot_data
# Out:
#     Unnamed: 0       acc    auc_sc                                    bp  \
# 2          NaN  0.926543  0.812781        criterion gini;random_state 42
# 5          NaN  0.926543  0.812781        criterion gini;random_state 42
# 8          NaN  0.924584  0.805488        criterion gini;random_state 42
# 9          NaN  0.937316  0.888416  C 0.05;kernel linear;random_state 42
# 10         NaN  0.954946  0.899246                              ensemble
# 13         NaN  0.890304  0.721502        criterion gini;random_state 42
# 16         NaN  0.890304  0.721502        criterion gini;random_state 42
# 19         NaN  0.892262  0.722706     criterion entropy;random_state 42
# 22         NaN  0.918707  0.791728        criterion gini;random_state 42
# 25         NaN  0.918707  0.791728        criterion gini;random_state 42
# 28         NaN  0.920666  0.792932        criterion gini;random_state 42
# 31         NaN  0.887365  0.713608        criterion gini;random_state 42
# 34         NaN  0.887365  0.713608        criterion gini;random_state 42
# 37         NaN  0.876592  0.682630     criterion entropy;random_state 42
# 40         NaN  0.871694  0.689771     criterion entropy;random_state 42
# 60         NaN  0.877571  0.681202        criterion gini;random_state 42
# 61         NaN  0.919687  0.851197     C 1;kernel linear;random_state 42
# 62         NaN  0.918707  0.834356                              ensemble
# 65         NaN  0.879530  0.694585     criterion entropy;random_state 42
# 66         NaN  0.929481  0.875483     C 1;kernel linear;random_state 42
# 67         NaN  0.929481  0.847064                              ensemble
# 70         NaN  0.892262  0.722706     criterion entropy;random_state 42
# 71         NaN  0.939275  0.875410   C 0.1;kernel linear;random_state 42
# 72         NaN  0.939275  0.871350                              ensemble
# 75         NaN  0.886386  0.710976     criterion entropy;random_state 42
# 76         NaN  0.953967  0.902704  C 0.05;kernel linear;random_state 42
# 77         NaN  0.951028  0.892780                              ensemble
# 80         NaN  0.892262  0.730825     criterion entropy;random_state 42
# 81         NaN  0.929481  0.849094       C 10;kernel rbf;random_state 42
# 82         NaN  0.931440  0.854357                              ensemble
# 85         NaN  0.886386  0.704886     criterion entropy;random_state 42
# 86         NaN  0.922625  0.859092    C 10;kernel linear;random_state 42
# 87         NaN  0.922625  0.842853                              ensemble
# 90         NaN  0.873653  0.676765     criterion entropy;random_state 42
# 91         NaN  0.949070  0.889547       C 10;kernel rbf;random_state 42
# 92         NaN  0.943193  0.883907                              ensemble
# 95         NaN  0.885406  0.704285     criterion entropy;random_state 42
# 96         NaN  0.955926  0.909997       C 10;kernel rbf;random_state 42
# 97         NaN  0.946131  0.899921                              ensemble
#
#          f_1     fn    fp                     name         p         r  \
# 2   0.761905   70.0   5.0                       rf  0.960000  0.631579
# 5   0.761905   70.0   5.0                       rf  0.960000  0.631579
# 8   0.752412   73.0   4.0                       rf  0.966942  0.615789
# 9   0.827957   36.0  28.0                      svm  0.846154  0.810526
# 10  0.870056   36.0  10.0  ensemble (lr,svc,dt,rf)  0.939024  0.810526
# 13  0.605634  104.0   8.0                       rf  0.914894  0.452632
# 16  0.605634  104.0   8.0                       rf  0.914894  0.452632
# 19  0.609929  104.0   6.0                       rf  0.934783  0.452632
# 22  0.729642   78.0   5.0                       rf  0.957265  0.589474
# 25  0.729642   78.0   5.0                       rf  0.957265  0.589474
# 28  0.734426   78.0   3.0                       rf  0.973913  0.589474
# 31  0.590747  107.0   8.0                       rf  0.912088  0.436842
# 34  0.590747  107.0   8.0                       rf  0.912088  0.436842
# 37  0.529851  119.0   7.0                       rf  0.910256  0.373684
# 40  0.537102  114.0  17.0                       rf  0.817204  0.400000
# 60  0.528302  120.0   5.0                       rf  0.933333  0.368421
# 61  0.774725   49.0  33.0                      svm  0.810345  0.742105
# 62  0.762178   57.0  26.0        ensemble (lr,svc)  0.836478  0.700000
# 65  0.552727  114.0   9.0                       rf  0.894118  0.400000
# 66  0.806452   40.0  32.0                      svm  0.824176  0.789474
# 67  0.790698   54.0  18.0        ensemble (lr,svc)  0.883117  0.715789
# 70  0.609929  104.0   6.0                       rf  0.934783  0.452632
# 71  0.825843   43.0  19.0                      svm  0.885542  0.773684
# 72  0.823864   45.0  17.0        ensemble (lr,svc)  0.895062  0.763158
# 75  0.585714  108.0   8.0                       rf  0.911111  0.431579
# 76  0.869081   34.0  13.0                      svm  0.923077  0.821053
# 77  0.858757   38.0  12.0        ensemble (lr,svc)  0.926829  0.800000
# 80  0.620690  100.0  10.0                       rf  0.900000  0.473684
# 81  0.791908   53.0  19.0                      svm  0.878205  0.721053
# 82  0.798851   51.0  19.0        ensemble (lr,svc)  0.879747  0.731579
# 85  0.576642  111.0   5.0                       rf  0.940476  0.415789
# 86  0.784741   46.0  33.0                      svm  0.813559  0.757895
# 87  0.774929   54.0  25.0        ensemble (lr,svc)  0.844720  0.715789
# 90  0.516854  121.0   8.0                       rf  0.896104  0.363158
# 91  0.853107   39.0  13.0                      svm  0.920732  0.794737
# 92  0.837989   40.0  18.0        ensemble (lr,svc)  0.892857  0.789474
# 95  0.574545  111.0   6.0                       rf  0.929412  0.415789
# 96  0.876033   31.0  14.0                      svm  0.919075  0.836842
# 97  0.850949   33.0  22.0        ensemble (lr,svc)  0.877095  0.826316
#
#                                                tf     tn     tp  \
# 2            features/df_tweet_tfidf_train.pickle  826.0  120.0
# 5               features/df_tweet_tf_train.pickle  826.0  120.0
# 8                  features/df_tweet_train.pickle  827.0  117.0
# 9                  features/df_tweet_train.pickle  803.0  154.0
# 10                 features/df_tweet_train.pickle  821.0  154.0
# 13        features/df_tweetbio_tfidf_train.pickle  823.0   86.0
# 16           features/df_tweetbio_tf_train.pickle  823.0   86.0
# 19              features/df_tweetbio_train.pickle  825.0   86.0
# 22        features/df_tweet_tfidf_train_nc.pickle  826.0  112.0
# 25           features/df_tweet_tf_train_nc.pickle  826.0  112.0
# 28              features/df_tweet_train_nc.pickle  828.0  112.0
# 31     features/df_tweetbio_tfidf_train_nc.pickle  823.0   83.0
# 34        features/df_tweetbio_tf_train_nc.pickle  823.0   83.0
# 37           features/df_tweetbio_train_nc.pickle  824.0   71.0
# 40  features/df_tweet_count_features_train.pickle  814.0   76.0
# 60                               fasttext_300_sum  826.0   70.0
# 61                               fasttext_300_sum  798.0  141.0
# 62                               fasttext_300_sum  805.0  133.0
# 65                    fasttext_300_sum_plusCounts  822.0   76.0
# 66                    fasttext_300_sum_plusCounts  799.0  150.0
# 67                    fasttext_300_sum_plusCounts  813.0  136.0
# 70                                  glove_300_sum  825.0   86.0
# 71                                  glove_300_sum  812.0  147.0
# 72                                  glove_300_sum  814.0  145.0
# 75                       glove_300_sum_plusCounts  823.0   82.0
# 76                       glove_300_sum_plusCounts  818.0  156.0
# 77                       glove_300_sum_plusCounts  819.0  152.0
# 80                           glove_twitter200_sum  821.0   90.0
# 81                           glove_twitter200_sum  812.0  137.0
# 82                           glove_twitter200_sum  812.0  139.0
# 85                glove_twitter200_sum_plusCounts  826.0   79.0
# 86                glove_twitter200_sum_plusCounts  798.0  144.0
# 87                glove_twitter200_sum_plusCounts  806.0  136.0
# 90                                    w2v_300_sum  823.0   69.0
# 91                                    w2v_300_sum  818.0  151.0
# 92                                    w2v_300_sum  813.0  150.0
# 95                         w2v_300_sum_plusCounts  825.0   79.0
# 96                         w2v_300_sum_plusCounts  817.0  159.0
# 97                         w2v_300_sum_plusCounts  809.0  157.0
#
#                       group     features calc  Unnamed: 4
# 2      classic vector space    VSM_TFIDF    y         NaN
# 5      classic vector space       VSM_TF    y         NaN
# 8      classic vector space    VSM_count    y         NaN
# 9      classic vector space    VSM_count    y         NaN
# 10     classic vector space    VSM_count    y         NaN
# 13     classic vector space    VSM_TFIDF    y         NaN
# 16     classic vector space       VSM_TF    y         NaN
# 19     classic vector space    VSM_count    y         NaN
# 22     classic vector space    VSM_TFIDF    n         NaN
# 25     classic vector space       VSM_TF    n         NaN
# 28     classic vector space    VSM_count    n         NaN
# 31     classic vector space    VSM_TFIDF    n         NaN
# 34     classic vector space       VSM_TF    n         NaN
# 37     classic vector space    VSM_count    n         NaN
# 40     classic vector space   calculated    y         NaN
# 60  classic word embeddings  FastText300    n         NaN
# 61  classic word embeddings  FastText300    n         NaN
# 62  classic word embeddings  FastText300    n         NaN
# 65  classic word embeddings  FastText300    y         NaN
# 66  classic word embeddings  FastText300    y         NaN
# 67  classic word embeddings  FastText300    y         NaN
# 70  classic word embeddings     GloVe300    n         NaN
# 71  classic word embeddings     GloVe300    n         NaN
# 72  classic word embeddings     GloVe300    n         NaN
# 75  classic word embeddings     GloVe300    y         NaN
# 76  classic word embeddings     GloVe300    y         NaN
# 77  classic word embeddings     GloVe300    y         NaN
# 80  classic word embeddings     GloVe200    n         NaN
# 81  classic word embeddings     GloVe200    n         NaN
# 82  classic word embeddings     GloVe200    n         NaN
# 85  classic word embeddings     GloVe200    y         NaN
# 86  classic word embeddings     GloVe200    y         NaN
# 87  classic word embeddings     GloVe200    y         NaN
# 90  classic word embeddings       w2v300    n         NaN
# 91  classic word embeddings       w2v300    n         NaN
# 92  classic word embeddings       w2v300    n         NaN
# 95  classic word embeddings       w2v300    y         NaN
# 96  classic word embeddings       w2v300    y         NaN
# 97  classic word embeddings       w2v300    y         NaN

# %%
plot_data = metrics[metrics['group'].isin(['classic vector space','classic word embeddings'])]
plot_data['name'].isin(['lr','dt'])
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
#       ...
# 93     True
# 94     True
# 95    False
# 96    False
# 97    False
# Name: name, Length: 81, dtype: bool

# %%
plt.figure(figsize=(16, 6))

group_field = 'name'
metric_field = 'f_1'
x = metrics.groupby([group_field], sort=True)[metric_field].max().reset_index()
x = x.sort_values(by=metric_field, ascending=False)


sort = x[group_field]
ax = sns.boxplot(x=group_field, y=metric_field, data=metrics, order=sort)
ax = sns.swarmplot(x=group_field, y=metric_field, data=metrics, color=".25", order=sort, size=10)

# %%
x
# Out:
#                      group       f_1
# 5  classic word embeddings  0.876033
# 4     classic vector space  0.870056
# 3   classic doc embeddings  0.787879
# 2           RNN embeddings  0.913043
# 1           CNN embeddings  0.835165
# 0                     BERT  0.929730

# %% [markdown]
# ## Counts of positives and negatives per tweet

# %%
df_check = class_results_pivot.copy() #copy the detailed results
model_counts = len(df_check.columns)-1 #count the total number of models in df_check
df_check['count_positive'] = df_check.sum(axis=1) #create a column counting the number of positives
df_check = pd.merge(df_check, actual_class, on='tweet_id') #merge the actual class for each tweet
df_check = df_check.loc[:,['tweet_id','count_positive','class_column']]   #create dataframe with the actual class and the
df_check['count_negative'] = model_counts - df_check['count_positive']    #counts of positive and negative predictions per tweet

# %%
t_id = [] #array to hold tweet ids
tweet = [] #array to hold tweet texts
desc = [] #classifier and feature combo
count = [] #number of classifier/feature combos classifying correctly
t = [] #the type of correct classification

for n in range(0,10): #n is the number of classifier/feature combos that got the right classification
    tweet_list = df_check[(df_check.count_negative==n)&(df_check.class_column==0)].tweet_id #negative class 
    if n==0:                                                                                #tweets with n negative 
        if (len(tweet_list)>0): #if there are tweets without correct classification         #correct classifiers
            t_id = np.append(t_id,tweet_list) #append tweet ids
            tweet = np.append(tweet,eval_data_formatted[eval_data_formatted['Tweet ID'].isin(tweet_list)].Tweet) #append tweet text
            desc = np.append(desc,np.repeat('no models',len(tweet_list))) #append classifier and feature combo description
            count = np.append(count,np.repeat(n,len(tweet_list))) #append number of classifier/feature combos classifying correctly
            t = np.append(t,np.repeat('tn',len(tweet_list))) #append the type of correct classification
    else:
        for tw_id in tweet_list: #go through each tweet id
            t_id = np.append(t_id,np.repeat(tw_id,n)) #append tweet id
            tweet = np.append(tweet,np.repeat(eval_data_formatted[eval_data_formatted['Tweet ID']==tw_id].Tweet,n)) #tweet text
            desc = np.append(desc,class_results[(class_results.pred==0)&(class_results.tweet_id==tw_id)].desc) #classifier/feature combo
            count = np.append(count,np.repeat(n,n)) #append number of classifier/feature combos classifying correctly
            t = np.append(t,np.repeat('tn',n)) #append the type of correct classification
            
            
    tweet_list = df_check[(df_check.count_positive==n)&(df_check.class_column==1)].tweet_id #positive class
    if n==0:                                                                                #tweets with n negative 
        if (len(tweet_list)>0): #if there are tweets without correct classification         #correct classifiers
            t_id = np.append(t_id,tweet_list) #append tweet ids
            tweet = np.append(tweet,eval_data_formatted[eval_data_formatted['Tweet ID'].isin(tweet_list)].Tweet) #append tweet text
            desc = np.append(desc,np.repeat('no models',len(tweet_list))) #append classifier and feature combo description
            count = np.append(count,np.repeat(n,len(tweet_list))) #append number of classifier/feature combos classifying correctly
            t = np.append(t,np.repeat('tp',len(tweet_list))) #append the type of correct classification
    else:
        for tw_id in tweet_list: #go through each tweet id
            t_id = np.append(t_id,np.repeat(tw_id,n)) #append tweet id
            tweet = np.append(tweet,np.repeat(eval_data_formatted[eval_data_formatted['Tweet ID']==tw_id].Tweet,n)) #tweet text
            desc = np.append(desc,class_results[(class_results.pred==1)&(class_results.tweet_id==tw_id)].desc) #classifier/feature combo
            count = np.append(count,np.repeat(n,n)) #append number of classifier/feature combos classifying correctly
            t = np.append(t,np.repeat('tp',n)) #append the type of correct classification            
            
            
print(len(t_id))
print(len(tweet))
print(len(desc))
print(len(count))
print(len(t))
# Out:
# 44
# 44
# 44
# 44
# 44

# %%
#Set the display.max_colwidth option to -1:

pd.options.display.max_colwidth = 280
df = pd.DataFrame({'t_id':t_id,'tweet':tweet,'desc':desc,'count':count,'t':t})
df
# Out:
#                   t_id  \
# 0   888118576573325312
# 1   888118576573325312
# 2   910247211031781376
# 3   910247211031781376
# 4  1153765869761302529
# 5  1153765869761302529
# 6  1153765869761302529
#
#                                                                                                                             tweet  \
# 0                This may be a blessing in disguise. I'm enjoying all this Sturgeon news in the mean time. The Scottish dwarf an…
# 1                This may be a blessing in disguise. I'm enjoying all this Sturgeon news in the mean time. The Scottish dwarf an…
# 2  As Andrew Neil steps down from his Sunday Politics role, a reminder of the time he called Sturgeon a 'Tipsy Scotch Tart'. htt…
# 3  As Andrew Neil steps down from his Sunday Politics role, a reminder of the time he called Sturgeon a 'Tipsy Scotch Tart'. htt…
# 4                                                                                        Nicola sturgeon has a face I would punch
# 5                                                                                        Nicola sturgeon has a face I would punch
# 6                                                                                        Nicola sturgeon has a face I would punch
#
#                                                           desc  count   t
# 0              dt model using features/df_tweet_eval_nc.pickle    2.0  tp
# 1          cnn_glove300 model using eval_data_formatted.pickle    2.0  tp
# 2  dt model using features/df_tweet_count_features_eval.pickle    2.0  tp
# 3                   dt model using fasttext_300_sum_plusCounts    2.0  tp
# 4  lr model using features/df_tweet_count_features_eval.pickle    3.0  tn
# 5  dt model using features/df_tweet_count_features_eval.pickle    3.0  tn
# 6                                   rf model using w2v_300_sum    3.0  tn

# %%
#negative class tweets where all classifiers were correct
df_check[(df_check.count_negative==model_counts)&(df_check.class_column==0)].tweet_id
# Out:
# 0      1146950933437399040
# 2      1147011915782217729
# 7      1147105421477519360
# 8      1147126096934125568
# 9      1147151158869291009
#               ...
# 825    1157974240106352640
# 827    1157974330657169408
# 828    1157974611818102784
# 829    1157974810833686529
# 830    1157974989318033415
# Name: tweet_id, Length: 365, dtype: object

# %%
#positive class tweets where all classifiers were correct
df_check[(df_check.count_positive==model_counts-2)&(df_check.class_column==1)].tweet_id
# Out:
# 841     839520775027699713
# 883     842483329576435712
# 987     902473790403248128
# 1013    906431625009025024
# Name: tweet_id, dtype: object
