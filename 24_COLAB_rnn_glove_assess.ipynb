# %% [markdown]
# ## Common imports

# %%
#based on code accessed on 21/10/2019 from https://towardsdatascience.com/machine-learning-word-embedding-sentiment-classification-using-keras-b83c28087456 
import pandas as pd
import numpy as np

# %% [markdown]
# ## Upload data

# %%
! wget -cq https://github.com/ScottJK-20190706/tweet_classifier/blob/master/pickle_files//train_data_formatted.pickle?raw=true
! wget -cq https://github.com/ScottJK-20190706/tweet_classifier/blob/master/pickle_files/eval_data_formatted.pickle?raw=true
train_data = pd.read_pickle('train_data_formatted.pickle?raw=true')
eval_data = pd.read_pickle('eval_data_formatted.pickle?raw=true')
all_data = train_data.append(eval_data).reset_index(drop=True)

# %% [markdown]
# ## Tokenise each tweet

# %%
import string
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

tweet_lines = list()
lines = all_data['Tweet'].values.tolist()

for line in lines:
  tokens = word_tokenize(line)
  tokens = [w.lower() for w in tokens]
  table = str.maketrans('','',string.punctuation)
  stripped = [w.translate(table) for w in tokens]
  words = [word for word in stripped if word.isalpha()]
  stop_words = set(stopwords.words('english'))
  words = [w for w in words if not w in stop_words]
  tweet_lines.append(words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Convert each tweet into array of integers corresponding to each word

# %%
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences

tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(tweet_lines)
sequences = tokenizer_obj.texts_to_sequences(tweet_lines)

word_index = tokenizer_obj.word_index
print('found %s unique tokens' % len(word_index))

max_length = len(max(tweet_lines,key=len))
tweet_pad = pad_sequences(sequences, maxlen=max_length)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# found 7426 unique tokens

# %%
len(tweet_pad)
# Out:
# 5104

# %% [markdown]
# ## Obtain the word embeddings

# %%
# !pip install chakin #word embeddings
import chakin
chakin.search(lang='English')
chakin.download(number=16, save_dir='/tmp/') # select GloVe.840B.300d
# Out:
# Collecting chakin
#   Downloading https://files.pythonhosted.org/packages/ca/3f/ca2f63451c0ab47970a6ab1d39d96118e70b6e73125529cea767c31368a3/chakin-0.0.8-py3-none-any.whl
# Requirement already satisfied: progressbar2>=3.20.0 in /usr/local/lib/python3.6/dist-packages (from chakin) (3.38.0)
# Requirement already satisfied: pandas>=0.20.1 in /usr/local/lib/python3.6/dist-packages (from chakin) (0.25.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from chakin) (1.12.0)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from progressbar2>=3.20.0->chakin) (2.3.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.1->chakin) (1.17.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.1->chakin) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.1->chakin) (2018.9)
# Installing collected packages: chakin
# Successfully installed chakin-0.0.8
#                    Name  Dimension  ... Language    Author
# 2          fastText(en)        300  ...  English  Facebook
# 11         GloVe.6B.50d         50  ...  English  Stanford
# 12        GloVe.6B.100d        100  ...  English  Stanford
# 13        GloVe.6B.200d        200  ...  English  Stanford
# 14        GloVe.6B.300d        300  ...  English  Stanford
# 15       GloVe.42B.300d        300  ...  English  Stanford
# 16      GloVe.840B.300d        300  ...  English  Stanford
# 17    GloVe.Twitter.25d         25  ...  English  Stanford
# 18    GloVe.Twitter.50d         50  ...  English  Stanford
# 19   GloVe.Twitter.100d        100  ...  English  Stanford
# 20   GloVe.Twitter.200d        200  ...  English  Stanford
# 21  word2vec.GoogleNews        300  ...  English    Google
#
# [12 rows x 7 columns]
# Test: 100% ||                                      | Time:  0:16:52   2.0 MiB/s
# '/tmp/glove.840B.300d.zip'

# %%
from zipfile import ZipFile
with ZipFile('/tmp/glove.840B.300d.zip', 'r') as zipObj:
   # Extract all the contents of zip file in current directory
  zipObj.extractall()

# %%
#code adapted from https://stackoverflow.com/questions/37793118/load-pretrained-glove-vectors-in-python
def loadGloveModel(gloveFile):
    print("Loading Glove Model")
    f = open(gloveFile,'r')
    model = {}
    for line in f:
        splitLine = line.split(' ')
        word = splitLine[0]
        embedding = np.array([float(val) for val in splitLine[1:]])
        model[word] = embedding
    print("Done.",len(model)," words loaded!")
    return model

# %%
w = loadGloveModel('glove.840B.300d.txt')
# Out:
# Loading Glove Model
# Done. 2196016  words loaded!

# %% [markdown]
# ## Create the embedding matrix
# Integer values in tweet_pad align with rows in embedding_matrix

# %%
num_words = len(word_index)+1
embedding_matrix = np.zeros((num_words,300))

for word, i in word_index.items():
  if i > num_words:
    continue
  try:
    embedding_vector = w[word]
  except:
    embedding_vector = np.zeros(300)
  #if embedding_vector is not None:
  embedding_matrix[i] = embedding_vector

# %% [markdown]
# ## 10 stratified splits of the data.  Train model and assess 10 times.

# %%
model_run = []
name = []
tn = []
fp = []
fn = []
tp = []
p = []
r = []
f_1 = []
auc_sc = []
acc = []

n = 0

from sklearn.model_selection import StratifiedShuffleSplit
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, GRU, Bidirectional
from keras.layers.embeddings import Embedding
from keras.initializers import Constant
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, auc, roc_curve, accuracy_score #metrics


sss = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=0)
for train_index, test_index in sss.split(all_data['Tweet'], all_data['class']):

  ##### CREATE TRAIN AND EVAL #####
  X_train_pad = tweet_pad[train_index]
  y_train = all_data.loc[train_index,'class'].values
  X_test_pad = tweet_pad[test_index]
  y_test = all_data.loc[test_index,'class'].values


  ##### BUILD RNN MODEL #####
  model = Sequential()
  embedding_layer = Embedding(num_words,
                            300,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length = max_length,
                            trainable = False)
  model.add(embedding_layer)
  model.add(GRU(units=64, dropout=0.4, recurrent_dropout=0.4))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  print(model.summary())

  ##### TRAIN MODEL #####
  model.fit(X_train_pad, y_train, batch_size=32, epochs=25, validation_data=(X_test_pad,y_test), verbose=2)

  ##### EVALUATION METRICS #####
  predict_proba = model.predict(x=X_test_pad)
  predict_class = predict_proba.copy()
  predict_class[predict_class >= 0.5] = 1
  predict_class[predict_class < 0.5] = 0

  conf_matrix = confusion_matrix(y_test,predict_class) #build confusion matrix
  precision = precision_score(y_test,predict_class) #calculate precision
  recall = recall_score(y_test,predict_class) #calculate recall
  f1 = f1_score(y_test,predict_class) #calculate f1
  fpr, tpr, thresholds = roc_curve(y_test,predict_class)
  auc_score = auc(fpr, tpr) #calculate auc
  accuracy = accuracy_score(y_test,predict_class) #calculate accuracy
  print(conf_matrix)
  print('precision = ' + str(precision))
  print('recall = ' + str(recall))
  print('f1 = ' + str(f1))
  print('auc = ' + str(auc_score))
  print('accuracy = ' + str(accuracy))

  model_run = np.append(model_run,n)
  name = np.append(name,'rnn_glove')
  tn = np.append(tn,conf_matrix[0][0])
  fp = np.append(fp,conf_matrix[0][1])
  fn = np.append(fn,conf_matrix[1][0])
  tp = np.append(tp,conf_matrix[1][1])
  p = np.append(p,precision)
  r = np.append(r,recall)
  f_1 = np.append(f_1,f1)
  auc_sc = np.append(auc_sc,auc_score)
  acc = np.append(acc,accuracy)

  n = n+1
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 42, 300)           2228100
# _________________________________________________________________
# gru_3 (GRU)                  (None, 64)                70080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,298,245
# Trainable params: 70,145
# Non-trainable params: 2,228,100
# _________________________________________________________________
# None
# Train on 4083 samples, validate on 1021 samples
# Epoch 1/25
#  - 7s - loss: 0.3112 - acc: 0.8771 - val_loss: 0.1863 - val_acc: 0.9216
# Epoch 2/25
#  - 5s - loss: 0.1852 - acc: 0.9292 - val_loss: 0.1344 - val_acc: 0.9471
# Epoch 3/25
#  - 5s - loss: 0.1521 - acc: 0.9439 - val_loss: 0.1273 - val_acc: 0.9500
# Epoch 4/25
#  - 5s - loss: 0.1310 - acc: 0.9515 - val_loss: 0.1179 - val_acc: 0.9481
# Epoch 5/25
#  - 5s - loss: 0.1172 - acc: 0.9559 - val_loss: 0.1062 - val_acc: 0.9569
# Epoch 6/25
#  - 5s - loss: 0.1014 - acc: 0.9633 - val_loss: 0.1010 - val_acc: 0.9579
# Epoch 7/25
#  - 5s - loss: 0.0927 - acc: 0.9628 - val_loss: 0.0978 - val_acc: 0.9598
# Epoch 8/25
#  - 5s - loss: 0.0801 - acc: 0.9709 - val_loss: 0.0973 - val_acc: 0.9598
# Epoch 9/25
#  - 5s - loss: 0.0781 - acc: 0.9706 - val_loss: 0.0894 - val_acc: 0.9628
# Epoch 10/25
#  - 5s - loss: 0.0690 - acc: 0.9755 - val_loss: 0.0893 - val_acc: 0.9628
# Epoch 11/25
#  - 5s - loss: 0.0645 - acc: 0.9753 - val_loss: 0.0869 - val_acc: 0.9667
# Epoch 12/25
#  - 5s - loss: 0.0602 - acc: 0.9767 - val_loss: 0.0906 - val_acc: 0.9657
# Epoch 13/25
#  - 5s - loss: 0.0561 - acc: 0.9787 - val_loss: 0.0951 - val_acc: 0.9657
# Epoch 14/25
#  - 5s - loss: 0.0479 - acc: 0.9819 - val_loss: 0.0926 - val_acc: 0.9638
# Epoch 15/25
#  - 5s - loss: 0.0456 - acc: 0.9824 - val_loss: 0.0881 - val_acc: 0.9647
# Epoch 16/25
#  - 5s - loss: 0.0411 - acc: 0.9858 - val_loss: 0.0937 - val_acc: 0.9667
# Epoch 17/25
#  - 5s - loss: 0.0318 - acc: 0.9887 - val_loss: 0.0996 - val_acc: 0.9706
# Epoch 18/25
#  - 5s - loss: 0.0345 - acc: 0.9890 - val_loss: 0.0957 - val_acc: 0.9687
# Epoch 19/25
#  - 5s - loss: 0.0346 - acc: 0.9882 - val_loss: 0.0928 - val_acc: 0.9667
# Epoch 20/25
#  - 5s - loss: 0.0347 - acc: 0.9878 - val_loss: 0.0983 - val_acc: 0.9667
# Epoch 21/25
#  - 5s - loss: 0.0326 - acc: 0.9882 - val_loss: 0.0954 - val_acc: 0.9667
# Epoch 22/25
#  - 5s - loss: 0.0265 - acc: 0.9902 - val_loss: 0.0996 - val_acc: 0.9667
# Epoch 23/25
#  - 5s - loss: 0.0246 - acc: 0.9919 - val_loss: 0.0986 - val_acc: 0.9677
# Epoch 24/25
#  - 5s - loss: 0.0242 - acc: 0.9914 - val_loss: 0.0973 - val_acc: 0.9667
# Epoch 25/25
#  - 5s - loss: 0.0267 - acc: 0.9897 - val_loss: 0.1002 - val_acc: 0.9677
# [[831  22]
#  [ 11 157]]
# precision = 0.8770949720670391
# recall = 0.9345238095238095
# f1 = 0.9048991354466859
# auc = 0.9543662423937921
# accuracy = 0.9676787463271302
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 42, 300)           2228100
# _________________________________________________________________
# gru_4 (GRU)                  (None, 64)                70080
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,298,245
# Trainable params: 70,145
# Non-trainable params: 2,228,100
# _________________________________________________________________
# None
# Train on 4083 samples, validate on 1021 samples
# Epoch 1/25
#  - 7s - loss: 0.2994 - acc: 0.8837 - val_loss: 0.2085 - val_acc: 0.9265
# Epoch 2/25
#  - 5s - loss: 0.1838 - acc: 0.9300 - val_loss: 0.1685 - val_acc: 0.9383
# Epoch 3/25
#  - 5s - loss: 0.1483 - acc: 0.9481 - val_loss: 0.1653 - val_acc: 0.9383
# Epoch 4/25
#  - 5s - loss: 0.1322 - acc: 0.9505 - val_loss: 0.1401 - val_acc: 0.9481
# Epoch 5/25
#  - 5s - loss: 0.1149 - acc: 0.9584 - val_loss: 0.1273 - val_acc: 0.9510
# Epoch 6/25
#  - 5s - loss: 0.0988 - acc: 0.9652 - val_loss: 0.1317 - val_acc: 0.9500
# Epoch 7/25
#  - 5s - loss: 0.0915 - acc: 0.9645 - val_loss: 0.1206 - val_acc: 0.9520
# Epoch 8/25
#  - 5s - loss: 0.0829 - acc: 0.9718 - val_loss: 0.1177 - val_acc: 0.9569
# Epoch 9/25
#  - 5s - loss: 0.0709 - acc: 0.9760 - val_loss: 0.1168 - val_acc: 0.9589
# Epoch 10/25
#  - 5s - loss: 0.0671 - acc: 0.9733 - val_loss: 0.1162 - val_acc: 0.9608
# Epoch 11/25
#  - 5s - loss: 0.0623 - acc: 0.9789 - val_loss: 0.1136 - val_acc: 0.9598
# Epoch 12/25
#  - 5s - loss: 0.0578 - acc: 0.9804 - val_loss: 0.1148 - val_acc: 0.9598
# Epoch 13/25
#  - 5s - loss: 0.0515 - acc: 0.9811 - val_loss: 0.1180 - val_acc: 0.9569
# Epoch 14/25
#  - 5s - loss: 0.0494 - acc: 0.9826 - val_loss: 0.1211 - val_acc: 0.9598
# Epoch 15/25
#  - 5s - loss: 0.0478 - acc: 0.9819 - val_loss: 0.1158 - val_acc: 0.9618
# Epoch 16/25
#  - 5s - loss: 0.0393 - acc: 0.9860 - val_loss: 0.1186 - val_acc: 0.9628
# Epoch 17/25
#  - 5s - loss: 0.0367 - acc: 0.9865 - val_loss: 0.1268 - val_acc: 0.9628
# Epoch 18/25
#  - 6s - loss: 0.0384 - acc: 0.9865 - val_loss: 0.1138 - val_acc: 0.9628
# Epoch 19/25
#  - 5s - loss: 0.0308 - acc: 0.9897 - val_loss: 0.1371 - val_acc: 0.9647
# Epoch 20/25
#  - 5s - loss: 0.0286 - acc: 0.9880 - val_loss: 0.1307 - val_acc: 0.9628
# Epoch 21/25
#  - 5s - loss: 0.0334 - acc: 0.9878 - val_loss: 0.1310 - val_acc: 0.9638
# Epoch 22/25
#  - 5s - loss: 0.0272 - acc: 0.9880 - val_loss: 0.1241 - val_acc: 0.9667
# Epoch 23/25
#  - 5s - loss: 0.0244 - acc: 0.9922 - val_loss: 0.1281 - val_acc: 0.9638
# Epoch 24/25
#  - 5s - loss: 0.0236 - acc: 0.9895 - val_loss: 0.1285 - val_acc: 0.9667
# Epoch 25/25
#  - 5s - loss: 0.0223 - acc: 0.9922 - val_loss: 0.1301 - val_acc: 0.9657
# [[834  19]
#  [ 16 152]]
# precision = 0.8888888888888888
# recall = 0.9047619047619048
# f1 = 0.8967551622418879
# auc = 0.9412437894266733
# accuracy = 0.9657198824681684
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 42, 300)           2228100
# _________________________________________________________________
# gru_5 (GRU)                  (None, 64)                70080
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,298,245
# Trainable params: 70,145
# Non-trainable params: 2,228,100
# _________________________________________________________________
# None
# Train on 4083 samples, validate on 1021 samples
# Epoch 1/25
#  - 7s - loss: 0.2918 - acc: 0.8854 - val_loss: 0.2015 - val_acc: 0.9216
# Epoch 2/25
#  - 5s - loss: 0.1818 - acc: 0.9358 - val_loss: 0.1656 - val_acc: 0.9363
# Epoch 3/25
#  - 5s - loss: 0.1544 - acc: 0.9476 - val_loss: 0.1484 - val_acc: 0.9461
# Epoch 4/25
#  - 5s - loss: 0.1231 - acc: 0.9552 - val_loss: 0.1423 - val_acc: 0.9500
# Epoch 5/25
#  - 5s - loss: 0.1097 - acc: 0.9589 - val_loss: 0.1414 - val_acc: 0.9500
# Epoch 6/25
#  - 5s - loss: 0.1023 - acc: 0.9591 - val_loss: 0.1442 - val_acc: 0.9510
# Epoch 7/25
#  - 5s - loss: 0.0823 - acc: 0.9713 - val_loss: 0.1403 - val_acc: 0.9549
# Epoch 8/25
#  - 6s - loss: 0.0727 - acc: 0.9740 - val_loss: 0.1343 - val_acc: 0.9559
# Epoch 9/25
#  - 6s - loss: 0.0679 - acc: 0.9735 - val_loss: 0.1335 - val_acc: 0.9618
# Epoch 10/25
#  - 5s - loss: 0.0614 - acc: 0.9750 - val_loss: 0.1448 - val_acc: 0.9540
# Epoch 11/25
#  - 5s - loss: 0.0559 - acc: 0.9777 - val_loss: 0.1523 - val_acc: 0.9559
# Epoch 12/25
#  - 5s - loss: 0.0509 - acc: 0.9799 - val_loss: 0.1456 - val_acc: 0.9569
# Epoch 13/25
#  - 5s - loss: 0.0533 - acc: 0.9797 - val_loss: 0.1417 - val_acc: 0.9559
# Epoch 14/25
#  - 5s - loss: 0.0448 - acc: 0.9851 - val_loss: 0.1423 - val_acc: 0.9579
# Epoch 15/25
#  - 5s - loss: 0.0356 - acc: 0.9868 - val_loss: 0.1608 - val_acc: 0.9559
# Epoch 16/25
#  - 5s - loss: 0.0340 - acc: 0.9878 - val_loss: 0.1657 - val_acc: 0.9628
# Epoch 17/25
#  - 5s - loss: 0.0338 - acc: 0.9890 - val_loss: 0.1449 - val_acc: 0.9618
# Epoch 18/25
#  - 5s - loss: 0.0324 - acc: 0.9882 - val_loss: 0.1435 - val_acc: 0.9608
# Epoch 19/25
#  - 5s - loss: 0.0342 - acc: 0.9860 - val_loss: 0.1594 - val_acc: 0.9549
# Epoch 20/25
#  - 5s - loss: 0.0287 - acc: 0.9900 - val_loss: 0.1647 - val_acc: 0.9618
# Epoch 21/25
#  - 5s - loss: 0.0246 - acc: 0.9919 - val_loss: 0.1604 - val_acc: 0.9608
# Epoch 22/25
#  - 5s - loss: 0.0269 - acc: 0.9904 - val_loss: 0.1571 - val_acc: 0.9589
# Epoch 23/25
#  - 5s - loss: 0.0229 - acc: 0.9909 - val_loss: 0.1676 - val_acc: 0.9628
# Epoch 24/25
#  - 5s - loss: 0.0222 - acc: 0.9927 - val_loss: 0.1664 - val_acc: 0.9598
# Epoch 25/25
#  - 5s - loss: 0.0237 - acc: 0.9929 - val_loss: 0.1678 - val_acc: 0.9589
# [[836  17]
#  [ 25 143]]
# precision = 0.89375
# recall = 0.8511904761904762
# f1 = 0.8719512195121951
# auc = 0.9156304080835148
# accuracy = 0.9588638589618022
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 42, 300)           2228100
# _________________________________________________________________
# gru_6 (GRU)                  (None, 64)                70080
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,298,245
# Trainable params: 70,145
# Non-trainable params: 2,228,100
# _________________________________________________________________
# None
# Train on 4083 samples, validate on 1021 samples
# Epoch 1/25
#  - 8s - loss: 0.3012 - acc: 0.8819 - val_loss: 0.2513 - val_acc: 0.9119
# Epoch 2/25
#  - 5s - loss: 0.1884 - acc: 0.9341 - val_loss: 0.1716 - val_acc: 0.9363
# Epoch 3/25
#  - 5s - loss: 0.1513 - acc: 0.9442 - val_loss: 0.1659 - val_acc: 0.9393
# Epoch 4/25
#  - 5s - loss: 0.1366 - acc: 0.9508 - val_loss: 0.1276 - val_acc: 0.9500
# Epoch 5/25
#  - 5s - loss: 0.1245 - acc: 0.9549 - val_loss: 0.1210 - val_acc: 0.9520
# Epoch 6/25
#  - 5s - loss: 0.1065 - acc: 0.9630 - val_loss: 0.1182 - val_acc: 0.9559
# Epoch 7/25
#  - 5s - loss: 0.0922 - acc: 0.9672 - val_loss: 0.1177 - val_acc: 0.9549
# Epoch 8/25
#  - 5s - loss: 0.0916 - acc: 0.9660 - val_loss: 0.1003 - val_acc: 0.9569
# Epoch 9/25
#  - 5s - loss: 0.0823 - acc: 0.9713 - val_loss: 0.0976 - val_acc: 0.9608
# Epoch 10/25
#  - 5s - loss: 0.0691 - acc: 0.9758 - val_loss: 0.1001 - val_acc: 0.9618
# Epoch 11/25
#  - 5s - loss: 0.0683 - acc: 0.9755 - val_loss: 0.0960 - val_acc: 0.9628
# Epoch 12/25
#  - 5s - loss: 0.0559 - acc: 0.9811 - val_loss: 0.0898 - val_acc: 0.9608
# Epoch 13/25
#  - 5s - loss: 0.0550 - acc: 0.9809 - val_loss: 0.0964 - val_acc: 0.9628
# Epoch 14/25
#  - 5s - loss: 0.0473 - acc: 0.9851 - val_loss: 0.0945 - val_acc: 0.9618
# Epoch 15/25
#  - 5s - loss: 0.0436 - acc: 0.9829 - val_loss: 0.0941 - val_acc: 0.9638
# Epoch 16/25
#  - 5s - loss: 0.0387 - acc: 0.9853 - val_loss: 0.0981 - val_acc: 0.9647
# Epoch 17/25
#  - 5s - loss: 0.0399 - acc: 0.9863 - val_loss: 0.0935 - val_acc: 0.9667
# Epoch 18/25
#  - 5s - loss: 0.0395 - acc: 0.9860 - val_loss: 0.1006 - val_acc: 0.9657
# Epoch 19/25
#  - 5s - loss: 0.0344 - acc: 0.9878 - val_loss: 0.0968 - val_acc: 0.9657
# Epoch 20/25
#  - 5s - loss: 0.0293 - acc: 0.9900 - val_loss: 0.0965 - val_acc: 0.9657
# Epoch 21/25
#  - 5s - loss: 0.0275 - acc: 0.9880 - val_loss: 0.1063 - val_acc: 0.9628
# Epoch 22/25
#  - 5s - loss: 0.0263 - acc: 0.9914 - val_loss: 0.1157 - val_acc: 0.9618
# Epoch 23/25
#  - 5s - loss: 0.0277 - acc: 0.9882 - val_loss: 0.1139 - val_acc: 0.9657
# Epoch 24/25
#  - 5s - loss: 0.0274 - acc: 0.9887 - val_loss: 0.1220 - val_acc: 0.9638
# Epoch 25/25
#  - 5s - loss: 0.0225 - acc: 0.9924 - val_loss: 0.1345 - val_acc: 0.9598
# [[840  13]
#  [ 28 140]]
# precision = 0.9150326797385621
# recall = 0.8333333333333334
# f1 = 0.8722741433021807
# auc = 0.9090465025400548
# accuracy = 0.9598432908912831
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 42, 300)           2228100
# _________________________________________________________________
# gru_7 (GRU)                  (None, 64)                70080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,298,245
# Trainable params: 70,145
# Non-trainable params: 2,228,100
# _________________________________________________________________
# None
# Train on 4083 samples, validate on 1021 samples
# Epoch 1/25
#  - 8s - loss: 0.2963 - acc: 0.8859 - val_loss: 0.1828 - val_acc: 0.9265
# Epoch 2/25
#  - 5s - loss: 0.1833 - acc: 0.9304 - val_loss: 0.1508 - val_acc: 0.9373
# Epoch 3/25
#  - 5s - loss: 0.1489 - acc: 0.9451 - val_loss: 0.1250 - val_acc: 0.9559
# Epoch 4/25
#  - 5s - loss: 0.1303 - acc: 0.9552 - val_loss: 0.1151 - val_acc: 0.9579
# Epoch 5/25
#  - 5s - loss: 0.1198 - acc: 0.9579 - val_loss: 0.1081 - val_acc: 0.9579
# Epoch 6/25
#  - 5s - loss: 0.1025 - acc: 0.9613 - val_loss: 0.1081 - val_acc: 0.9589
# Epoch 7/25
#  - 5s - loss: 0.0929 - acc: 0.9682 - val_loss: 0.1023 - val_acc: 0.9589
# Epoch 8/25
#  - 5s - loss: 0.0870 - acc: 0.9660 - val_loss: 0.0913 - val_acc: 0.9647
# Epoch 9/25
#  - 5s - loss: 0.0777 - acc: 0.9711 - val_loss: 0.0863 - val_acc: 0.9687
# Epoch 10/25
#  - 5s - loss: 0.0718 - acc: 0.9758 - val_loss: 0.0896 - val_acc: 0.9696
# Epoch 11/25
#  - 5s - loss: 0.0699 - acc: 0.9753 - val_loss: 0.0875 - val_acc: 0.9687
# Epoch 12/25
#  - 5s - loss: 0.0582 - acc: 0.9762 - val_loss: 0.0986 - val_acc: 0.9667
# Epoch 13/25
#  - 5s - loss: 0.0522 - acc: 0.9809 - val_loss: 0.0948 - val_acc: 0.9677
# Epoch 14/25
#  - 6s - loss: 0.0532 - acc: 0.9816 - val_loss: 0.0858 - val_acc: 0.9716
# Epoch 15/25
#  - 6s - loss: 0.0467 - acc: 0.9831 - val_loss: 0.0966 - val_acc: 0.9677
# Epoch 16/25
#  - 5s - loss: 0.0452 - acc: 0.9846 - val_loss: 0.0916 - val_acc: 0.9687
# Epoch 17/25
#  - 5s - loss: 0.0392 - acc: 0.9865 - val_loss: 0.0916 - val_acc: 0.9706
# Epoch 18/25
#  - 5s - loss: 0.0387 - acc: 0.9875 - val_loss: 0.0945 - val_acc: 0.9638
# Epoch 19/25
#  - 5s - loss: 0.0343 - acc: 0.9873 - val_loss: 0.0851 - val_acc: 0.9745
# Epoch 20/25
#  - 5s - loss: 0.0278 - acc: 0.9909 - val_loss: 0.0897 - val_acc: 0.9687
# Epoch 21/25
#  - 5s - loss: 0.0274 - acc: 0.9890 - val_loss: 0.0989 - val_acc: 0.9706
# Epoch 22/25
#  - 5s - loss: 0.0303 - acc: 0.9887 - val_loss: 0.0902 - val_acc: 0.9726
# Epoch 23/25
#  - 5s - loss: 0.0277 - acc: 0.9912 - val_loss: 0.0911 - val_acc: 0.9736
# Epoch 24/25
#  - 5s - loss: 0.0274 - acc: 0.9924 - val_loss: 0.0942 - val_acc: 0.9726
# Epoch 25/25
#  - 5s - loss: 0.0290 - acc: 0.9892 - val_loss: 0.0934 - val_acc: 0.9726
# [[843  10]
#  [ 18 150]]
# precision = 0.9375
# recall = 0.8928571428571429
# f1 = 0.9146341463414636
# auc = 0.9405669067157929
# accuracy = 0.9725759059745348
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 42, 300)           2228100
# _________________________________________________________________
# gru_8 (GRU)                  (None, 64)                70080
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,298,245
# Trainable params: 70,145
# Non-trainable params: 2,228,100
# _________________________________________________________________
# None
# Train on 4083 samples, validate on 1021 samples
# Epoch 1/25
#  - 8s - loss: 0.2956 - acc: 0.8832 - val_loss: 0.1899 - val_acc: 0.9363
# Epoch 2/25
#  - 5s - loss: 0.1873 - acc: 0.9295 - val_loss: 0.1569 - val_acc: 0.9461
# Epoch 3/25
#  - 5s - loss: 0.1639 - acc: 0.9380 - val_loss: 0.1279 - val_acc: 0.9530
# Epoch 4/25
#  - 5s - loss: 0.1337 - acc: 0.9510 - val_loss: 0.1151 - val_acc: 0.9579
# Epoch 5/25
#  - 5s - loss: 0.1139 - acc: 0.9549 - val_loss: 0.1137 - val_acc: 0.9579
# Epoch 6/25
#  - 5s - loss: 0.0990 - acc: 0.9630 - val_loss: 0.1037 - val_acc: 0.9608
# Epoch 7/25
#  - 5s - loss: 0.0977 - acc: 0.9640 - val_loss: 0.0977 - val_acc: 0.9598
# Epoch 8/25
#  - 5s - loss: 0.0907 - acc: 0.9664 - val_loss: 0.0933 - val_acc: 0.9618
# Epoch 9/25
#  - 5s - loss: 0.0820 - acc: 0.9689 - val_loss: 0.0943 - val_acc: 0.9618
# Epoch 10/25
#  - 5s - loss: 0.0707 - acc: 0.9731 - val_loss: 0.0916 - val_acc: 0.9638
# Epoch 11/25
#  - 5s - loss: 0.0586 - acc: 0.9782 - val_loss: 0.0946 - val_acc: 0.9608
# Epoch 12/25
#  - 5s - loss: 0.0609 - acc: 0.9770 - val_loss: 0.0887 - val_acc: 0.9647
# Epoch 13/25
#  - 5s - loss: 0.0528 - acc: 0.9811 - val_loss: 0.0943 - val_acc: 0.9638
# Epoch 14/25
#  - 5s - loss: 0.0552 - acc: 0.9802 - val_loss: 0.0936 - val_acc: 0.9647
# Epoch 15/25
#  - 5s - loss: 0.0491 - acc: 0.9819 - val_loss: 0.0930 - val_acc: 0.9667
# Epoch 16/25
#  - 5s - loss: 0.0413 - acc: 0.9853 - val_loss: 0.0874 - val_acc: 0.9657
# Epoch 17/25
#  - 5s - loss: 0.0385 - acc: 0.9860 - val_loss: 0.0877 - val_acc: 0.9677
# Epoch 18/25
#  - 5s - loss: 0.0386 - acc: 0.9873 - val_loss: 0.0900 - val_acc: 0.9687
# Epoch 19/25
#  - 5s - loss: 0.0346 - acc: 0.9882 - val_loss: 0.0816 - val_acc: 0.9677
# Epoch 20/25
#  - 5s - loss: 0.0333 - acc: 0.9882 - val_loss: 0.0942 - val_acc: 0.9647
# Epoch 21/25
#  - 5s - loss: 0.0265 - acc: 0.9902 - val_loss: 0.0973 - val_acc: 0.9647
# Epoch 22/25
#  - 6s - loss: 0.0247 - acc: 0.9917 - val_loss: 0.0936 - val_acc: 0.9647
# Epoch 23/25
#  - 5s - loss: 0.0268 - acc: 0.9914 - val_loss: 0.0924 - val_acc: 0.9687
# Epoch 24/25
#  - 6s - loss: 0.0280 - acc: 0.9900 - val_loss: 0.0963 - val_acc: 0.9647
# Epoch 25/25
#  - 6s - loss: 0.0234 - acc: 0.9909 - val_loss: 0.0987 - val_acc: 0.9647
# [[840  13]
#  [ 23 145]]
# precision = 0.9177215189873418
# recall = 0.8630952380952381
# f1 = 0.8895705521472392
# auc = 0.9239274549210071
# accuracy = 0.9647404505386875
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 42, 300)           2228100
# _________________________________________________________________
# gru_9 (GRU)                  (None, 64)                70080
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,298,245
# Trainable params: 70,145
# Non-trainable params: 2,228,100
# _________________________________________________________________
# None
# Train on 4083 samples, validate on 1021 samples
# Epoch 1/25
#  - 9s - loss: 0.2904 - acc: 0.8876 - val_loss: 0.2155 - val_acc: 0.9148
# Epoch 2/25
#  - 5s - loss: 0.1828 - acc: 0.9375 - val_loss: 0.1562 - val_acc: 0.9363
# Epoch 3/25
#  - 6s - loss: 0.1551 - acc: 0.9444 - val_loss: 0.1320 - val_acc: 0.9471
# Epoch 4/25
#  - 5s - loss: 0.1285 - acc: 0.9510 - val_loss: 0.1137 - val_acc: 0.9559
# Epoch 5/25
#  - 5s - loss: 0.1119 - acc: 0.9598 - val_loss: 0.1129 - val_acc: 0.9491
# Epoch 6/25
#  - 5s - loss: 0.1045 - acc: 0.9598 - val_loss: 0.1000 - val_acc: 0.9608
# Epoch 7/25
#  - 5s - loss: 0.0966 - acc: 0.9635 - val_loss: 0.0986 - val_acc: 0.9608
# Epoch 8/25
#  - 5s - loss: 0.0759 - acc: 0.9711 - val_loss: 0.0985 - val_acc: 0.9628
# Epoch 9/25
#  - 5s - loss: 0.0717 - acc: 0.9738 - val_loss: 0.1049 - val_acc: 0.9589
# Epoch 10/25
#  - 5s - loss: 0.0710 - acc: 0.9738 - val_loss: 0.0982 - val_acc: 0.9618
# Epoch 11/25
#  - 5s - loss: 0.0655 - acc: 0.9767 - val_loss: 0.0979 - val_acc: 0.9638
# Epoch 12/25
#  - 5s - loss: 0.0520 - acc: 0.9807 - val_loss: 0.1065 - val_acc: 0.9598
# Epoch 13/25
#  - 5s - loss: 0.0498 - acc: 0.9819 - val_loss: 0.1027 - val_acc: 0.9618
# Epoch 14/25
#  - 5s - loss: 0.0489 - acc: 0.9802 - val_loss: 0.1027 - val_acc: 0.9628
# Epoch 15/25
#  - 5s - loss: 0.0488 - acc: 0.9833 - val_loss: 0.1014 - val_acc: 0.9638
# Epoch 16/25
#  - 5s - loss: 0.0465 - acc: 0.9804 - val_loss: 0.0978 - val_acc: 0.9687
# Epoch 17/25
#  - 5s - loss: 0.0422 - acc: 0.9841 - val_loss: 0.0977 - val_acc: 0.9667
# Epoch 18/25
#  - 6s - loss: 0.0386 - acc: 0.9858 - val_loss: 0.1001 - val_acc: 0.9647
# Epoch 19/25
#  - 5s - loss: 0.0288 - acc: 0.9897 - val_loss: 0.1141 - val_acc: 0.9647
# Epoch 20/25
#  - 6s - loss: 0.0302 - acc: 0.9895 - val_loss: 0.1159 - val_acc: 0.9647
# Epoch 21/25
#  - 6s - loss: 0.0266 - acc: 0.9887 - val_loss: 0.1282 - val_acc: 0.9657
# Epoch 22/25
#  - 6s - loss: 0.0240 - acc: 0.9909 - val_loss: 0.1259 - val_acc: 0.9657
# Epoch 23/25
#  - 6s - loss: 0.0262 - acc: 0.9907 - val_loss: 0.1246 - val_acc: 0.9657
# Epoch 24/25
#  - 6s - loss: 0.0185 - acc: 0.9944 - val_loss: 0.1290 - val_acc: 0.9628
# Epoch 25/25
#  - 6s - loss: 0.0290 - acc: 0.9887 - val_loss: 0.1223 - val_acc: 0.9647
# [[835  18]
#  [ 18 150]]
# precision = 0.8928571428571429
# recall = 0.8928571428571429
# f1 = 0.8928571428571429
# auc = 0.9358775749455702
# accuracy = 0.9647404505386875
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (None, 42, 300)           2228100
# _________________________________________________________________
# gru_10 (GRU)                 (None, 64)                70080
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 2,298,245
# Trainable params: 70,145
# Non-trainable params: 2,228,100
# _________________________________________________________________
# None
# Train on 4083 samples, validate on 1021 samples
# Epoch 1/25
#  - 9s - loss: 0.3091 - acc: 0.8741 - val_loss: 0.1820 - val_acc: 0.9373
# Epoch 2/25
#  - 5s - loss: 0.1858 - acc: 0.9304 - val_loss: 0.1555 - val_acc: 0.9442
# Epoch 3/25
#  - 6s - loss: 0.1466 - acc: 0.9446 - val_loss: 0.1276 - val_acc: 0.9589
# Epoch 4/25
#  - 5s - loss: 0.1309 - acc: 0.9532 - val_loss: 0.1392 - val_acc: 0.9549
# Epoch 5/25
#  - 5s - loss: 0.1174 - acc: 0.9535 - val_loss: 0.1071 - val_acc: 0.9608
# Epoch 6/25
#  - 6s - loss: 0.1020 - acc: 0.9623 - val_loss: 0.1181 - val_acc: 0.9638
# Epoch 7/25
#  - 6s - loss: 0.0880 - acc: 0.9664 - val_loss: 0.1041 - val_acc: 0.9628
# Epoch 8/25
#  - 6s - loss: 0.0841 - acc: 0.9677 - val_loss: 0.0981 - val_acc: 0.9677
# Epoch 9/25
#  - 5s - loss: 0.0742 - acc: 0.9731 - val_loss: 0.0972 - val_acc: 0.9667
# Epoch 10/25
#  - 5s - loss: 0.0666 - acc: 0.9735 - val_loss: 0.1036 - val_acc: 0.9657
# Epoch 11/25
#  - 5s - loss: 0.0618 - acc: 0.9772 - val_loss: 0.0982 - val_acc: 0.9677
# Epoch 12/25
#  - 5s - loss: 0.0544 - acc: 0.9777 - val_loss: 0.0969 - val_acc: 0.9696
# Epoch 13/25
#  - 6s - loss: 0.0495 - acc: 0.9826 - val_loss: 0.0963 - val_acc: 0.9706
# Epoch 14/25
#  - 6s - loss: 0.0476 - acc: 0.9826 - val_loss: 0.0973 - val_acc: 0.9667
# Epoch 15/25
#  - 6s - loss: 0.0516 - acc: 0.9829 - val_loss: 0.0997 - val_acc: 0.9667
# Epoch 16/25
#  - 6s - loss: 0.0449 - acc: 0.9826 - val_loss: 0.1026 - val_acc: 0.9696
# Epoch 17/25
#  - 6s - loss: 0.0385 - acc: 0.9858 - val_loss: 0.1021 - val_acc: 0.9726
# Epoch 18/25
#  - 6s - loss: 0.0328 - acc: 0.9897 - val_loss: 0.1107 - val_acc: 0.9667
# Epoch 19/25
#  - 6s - loss: 0.0336 - acc: 0.9887 - val_loss: 0.0964 - val_acc: 0.9726
# Epoch 20/25
#  - 6s - loss: 0.0281 - acc: 0.9912 - val_loss: 0.1096 - val_acc: 0.9716
# Epoch 21/25
#  - 6s - loss: 0.0289 - acc: 0.9900 - val_loss: 0.1040 - val_acc: 0.9696
# Epoch 22/25
#  - 6s - loss: 0.0251 - acc: 0.9914 - val_loss: 0.1059 - val_acc: 0.9716
# Epoch 23/25
#  - 6s - loss: 0.0246 - acc: 0.9922 - val_loss: 0.1039 - val_acc: 0.9657
# Epoch 24/25
#  - 6s - loss: 0.0242 - acc: 0.9927 - val_loss: 0.1040 - val_acc: 0.9687
# Epoch 25/25
#  - 6s - loss: 0.0200 - acc: 0.9919 - val_loss: 0.1178 - val_acc: 0.9696
# [[842  11]
#  [ 20 148]]
# precision = 0.9308176100628931
# recall = 0.8809523809523809
# f1 = 0.9051987767584098
# auc = 0.9340283592921341
# accuracy = 0.9696376101860921
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_11 (Embedding)     (None, 42, 300)           2228100
# _________________________________________________________________
# gru_11 (GRU)                 (None, 64)                70080
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 2,298,245
# Trainable params: 70,145
# Non-trainable params: 2,228,100
# _________________________________________________________________
# None
# Train on 4083 samples, validate on 1021 samples
# Epoch 1/25
#  - 10s - loss: 0.2991 - acc: 0.8802 - val_loss: 0.1758 - val_acc: 0.9354
# Epoch 2/25
#  - 6s - loss: 0.1931 - acc: 0.9280 - val_loss: 0.1617 - val_acc: 0.9363
# Epoch 3/25
#  - 6s - loss: 0.1503 - acc: 0.9464 - val_loss: 0.1403 - val_acc: 0.9432
# Epoch 4/25
#  - 5s - loss: 0.1290 - acc: 0.9522 - val_loss: 0.1191 - val_acc: 0.9540
# Epoch 5/25
#  - 6s - loss: 0.1115 - acc: 0.9579 - val_loss: 0.1122 - val_acc: 0.9589
# Epoch 6/25
#  - 5s - loss: 0.1047 - acc: 0.9618 - val_loss: 0.1068 - val_acc: 0.9618
# Epoch 7/25
#  - 6s - loss: 0.0897 - acc: 0.9684 - val_loss: 0.0947 - val_acc: 0.9647
# Epoch 8/25
#  - 5s - loss: 0.0854 - acc: 0.9691 - val_loss: 0.0985 - val_acc: 0.9628
# Epoch 9/25
#  - 6s - loss: 0.0790 - acc: 0.9721 - val_loss: 0.0937 - val_acc: 0.9677
# Epoch 10/25
#  - 5s - loss: 0.0687 - acc: 0.9740 - val_loss: 0.0953 - val_acc: 0.9628
# Epoch 11/25
#  - 5s - loss: 0.0664 - acc: 0.9758 - val_loss: 0.0874 - val_acc: 0.9687
# Epoch 12/25
#  - 5s - loss: 0.0586 - acc: 0.9807 - val_loss: 0.0986 - val_acc: 0.9657
# Epoch 13/25
#  - 6s - loss: 0.0597 - acc: 0.9782 - val_loss: 0.0931 - val_acc: 0.9647
# Epoch 14/25
#  - 6s - loss: 0.0525 - acc: 0.9824 - val_loss: 0.0972 - val_acc: 0.9657
# Epoch 15/25
#  - 6s - loss: 0.0513 - acc: 0.9765 - val_loss: 0.1042 - val_acc: 0.9657
# Epoch 16/25
#  - 6s - loss: 0.0450 - acc: 0.9838 - val_loss: 0.1066 - val_acc: 0.9628
# Epoch 17/25
#  - 6s - loss: 0.0397 - acc: 0.9853 - val_loss: 0.1029 - val_acc: 0.9647
# Epoch 18/25
#  - 6s - loss: 0.0358 - acc: 0.9863 - val_loss: 0.1007 - val_acc: 0.9687
# Epoch 19/25
#  - 6s - loss: 0.0328 - acc: 0.9900 - val_loss: 0.1055 - val_acc: 0.9657
# Epoch 20/25
#  - 6s - loss: 0.0316 - acc: 0.9887 - val_loss: 0.1168 - val_acc: 0.9667
# Epoch 21/25
#  - 6s - loss: 0.0309 - acc: 0.9895 - val_loss: 0.1131 - val_acc: 0.9677
# Epoch 22/25
#  - 6s - loss: 0.0282 - acc: 0.9922 - val_loss: 0.1187 - val_acc: 0.9667
# Epoch 23/25
#  - 6s - loss: 0.0249 - acc: 0.9912 - val_loss: 0.1186 - val_acc: 0.9667
# Epoch 24/25
#  - 6s - loss: 0.0242 - acc: 0.9929 - val_loss: 0.1089 - val_acc: 0.9696
# Epoch 25/25
#  - 6s - loss: 0.0283 - acc: 0.9904 - val_loss: 0.0936 - val_acc: 0.9677
# [[836  17]
#  [ 16 152]]
# precision = 0.8994082840236687
# recall = 0.9047619047619048
# f1 = 0.9020771513353116
# auc = 0.942416122369229
# accuracy = 0.9676787463271302
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_12 (Embedding)     (None, 42, 300)           2228100
# _________________________________________________________________
# gru_12 (GRU)                 (None, 64)                70080
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 2,298,245
# Trainable params: 70,145
# Non-trainable params: 2,228,100
# _________________________________________________________________
# None
# Train on 4083 samples, validate on 1021 samples
# Epoch 1/25
#  - 10s - loss: 0.3091 - acc: 0.8751 - val_loss: 0.1912 - val_acc: 0.9363
# Epoch 2/25
#  - 6s - loss: 0.1890 - acc: 0.9282 - val_loss: 0.1595 - val_acc: 0.9452
# Epoch 3/25
#  - 5s - loss: 0.1574 - acc: 0.9400 - val_loss: 0.1396 - val_acc: 0.9530
# Epoch 4/25
#  - 5s - loss: 0.1285 - acc: 0.9513 - val_loss: 0.1320 - val_acc: 0.9589
# Epoch 5/25
#  - 6s - loss: 0.1159 - acc: 0.9574 - val_loss: 0.1433 - val_acc: 0.9579
# Epoch 6/25
#  - 6s - loss: 0.1061 - acc: 0.9598 - val_loss: 0.1264 - val_acc: 0.9559
# Epoch 7/25
#  - 5s - loss: 0.0932 - acc: 0.9672 - val_loss: 0.1256 - val_acc: 0.9579
# Epoch 8/25
#  - 6s - loss: 0.0842 - acc: 0.9682 - val_loss: 0.1180 - val_acc: 0.9579
# Epoch 9/25
#  - 5s - loss: 0.0748 - acc: 0.9696 - val_loss: 0.1177 - val_acc: 0.9589
# Epoch 10/25
#  - 6s - loss: 0.0689 - acc: 0.9760 - val_loss: 0.1140 - val_acc: 0.9618
# Epoch 11/25
#  - 5s - loss: 0.0630 - acc: 0.9787 - val_loss: 0.1131 - val_acc: 0.9589
# Epoch 12/25
#  - 6s - loss: 0.0583 - acc: 0.9765 - val_loss: 0.1137 - val_acc: 0.9618
# Epoch 13/25
#  - 5s - loss: 0.0462 - acc: 0.9819 - val_loss: 0.1172 - val_acc: 0.9579
# Epoch 14/25
#  - 5s - loss: 0.0486 - acc: 0.9809 - val_loss: 0.1211 - val_acc: 0.9618
# Epoch 15/25
#  - 5s - loss: 0.0415 - acc: 0.9858 - val_loss: 0.1158 - val_acc: 0.9618
# Epoch 16/25
#  - 6s - loss: 0.0436 - acc: 0.9821 - val_loss: 0.1203 - val_acc: 0.9618
# Epoch 17/25
#  - 5s - loss: 0.0378 - acc: 0.9863 - val_loss: 0.1216 - val_acc: 0.9628
# Epoch 18/25
#  - 6s - loss: 0.0333 - acc: 0.9887 - val_loss: 0.1383 - val_acc: 0.9608
# Epoch 19/25
#  - 6s - loss: 0.0328 - acc: 0.9875 - val_loss: 0.1351 - val_acc: 0.9608
# Epoch 20/25
#  - 5s - loss: 0.0318 - acc: 0.9882 - val_loss: 0.1326 - val_acc: 0.9647
# Epoch 21/25
#  - 6s - loss: 0.0297 - acc: 0.9878 - val_loss: 0.1357 - val_acc: 0.9559
# Epoch 22/25
#  - 6s - loss: 0.0309 - acc: 0.9895 - val_loss: 0.1371 - val_acc: 0.9598
# Epoch 23/25
#  - 6s - loss: 0.0252 - acc: 0.9912 - val_loss: 0.1349 - val_acc: 0.9598
# Epoch 24/25
#  - 6s - loss: 0.0288 - acc: 0.9897 - val_loss: 0.1381 - val_acc: 0.9608
# Epoch 25/25
#  - 5s - loss: 0.0250 - acc: 0.9919 - val_loss: 0.1328 - val_acc: 0.9628
# [[834  19]
#  [ 19 149]]
# precision = 0.8869047619047619
# recall = 0.8869047619047619
# f1 = 0.8869047619047619
# auc = 0.9323152179981019
# accuracy = 0.9627815866797258

# %%
metrics = pd.DataFrame({
  'model_run': model_run,  
  'name' : name,
  'tn' : tn,
  'fp' : fp,
  'fn' : fn,
  'tp' : tp,
  'p' : p,
  'r' : r,
  'f_1' : f_1,
  'auc_sc' : auc_sc,
  'acc' : acc  
})

# %%
metrics
# Out:
#    model_run       name     tn    fp  ...         r       f_1    auc_sc       acc
# 0        0.0  rnn_glove  831.0  22.0  ...  0.934524  0.904899  0.954366  0.967679
# 1        1.0  rnn_glove  834.0  19.0  ...  0.904762  0.896755  0.941244  0.965720
# 2        2.0  rnn_glove  836.0  17.0  ...  0.851190  0.871951  0.915630  0.958864
# 3        3.0  rnn_glove  840.0  13.0  ...  0.833333  0.872274  0.909047  0.959843
# 4        4.0  rnn_glove  843.0  10.0  ...  0.892857  0.914634  0.940567  0.972576
# 5        5.0  rnn_glove  840.0  13.0  ...  0.863095  0.889571  0.923927  0.964740
# 6        6.0  rnn_glove  835.0  18.0  ...  0.892857  0.892857  0.935878  0.964740
# 7        7.0  rnn_glove  842.0  11.0  ...  0.880952  0.905199  0.934028  0.969638
# 8        8.0  rnn_glove  836.0  17.0  ...  0.904762  0.902077  0.942416  0.967679
# 9        9.0  rnn_glove  834.0  19.0  ...  0.886905  0.886905  0.932315  0.962782
#
# [10 rows x 11 columns]

# %% [markdown]
# ## Authenticate location for saving files

# %%
# Set the output directory for saving model file
# Optionally, set a GCP bucket location
import tensorflow as tf

FILE_OUTPUT_DIR = 'glove_rnn_assess_files'#@param {type:"string"}
#@markdown Whether or not to clear/delete the directory and create a new one
DO_DELETE = True #@param {type:"boolean"}
#@markdown Set USE_BUCKET and BUCKET if you want to (optionally) store model output on GCP bucket.
USE_BUCKET = True #@param {type:"boolean"}
BUCKET = 'dissertation_bucket' #@param {type:"string"}

if USE_BUCKET:
  FILE_OUTPUT_DIR = 'gs://{}/{}'.format(BUCKET, FILE_OUTPUT_DIR)
  from google.colab import auth
  auth.authenticate_user()

if DO_DELETE:
  try:
    tf.gfile.DeleteRecursively(FILE_OUTPUT_DIR)
  except:
    # Doesn't matter if the directory didn't exist
    pass
tf.gfile.MakeDirs(FILE_OUTPUT_DIR)
print('***** File output directory: {} *****'.format(FILE_OUTPUT_DIR))
# Out:
# ***** File output directory: gs://dissertation_bucket/glove_rnn_assess_files *****

# %% [markdown]
# ## Save metrics and predictions per tweet

# %%
# !pip install gcsfs #google cloud storage
metrics.to_csv('gs://dissertation_bucket/glove_rnn_assess_files/metrics.csv')
# Out:
# Collecting gcsfs
#   Downloading https://files.pythonhosted.org/packages/ab/92/0297f2813cb240c52e90f8587420149970565800e019e1b08ef5ad28b6d9/gcsfs-0.3.1.tar.gz (43kB)
#      |████████████████████████████████| 51kB 2.1MB/s
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.6/dist-packages (from gcsfs) (1.4.2)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.6/dist-packages (from gcsfs) (0.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gcsfs) (2.21.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from gcsfs) (4.4.1)
# Requirement already satisfied: fsspec>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from gcsfs) (0.5.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs) (1.12.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs) (0.2.7)
# Requirement already satisfied: cachetools>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs) (3.1.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs) (4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib->gcsfs) (1.2.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gcsfs) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gcsfs) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gcsfs) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gcsfs) (2019.9.11)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.4.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.1.0)
# Building wheels for collected packages: gcsfs
#   Building wheel for gcsfs (setup.py) ... done
#   Created wheel for gcsfs: filename=gcsfs-0.3.1-py2.py3-none-any.whl size=17936 sha256=373d34d42d22d4097e10cf97f4dccebee08b0be03e0238ef7b6f02c619bdcd10
#   Stored in directory: /root/.cache/pip/wheels/9d/2b/6f/86954f0d8caa1173841e62bb780dc0f8693bd268e04a267682
# Successfully built gcsfs
# Installing collected packages: gcsfs
# Successfully installed gcsfs-0.3.1
